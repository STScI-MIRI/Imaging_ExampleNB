# %% [markdown]
# ## F770W - NGC 628 - skysub
#
# Author: Karl Gordon
#
# Last modified: 28 Jul 2022

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F770W"
fwhm = 2.2
basename = "jw02107039"
basename_bkg = "jw02107040"
exclude_above = None
ds9region = None

output_shape = None
crpix = None
crval = None
rotation = None

tweakreg = False
align_to_gaia = False

matchbkg = False

# display range for images
drange_raw = [12.0, 20.]
# display range for images
drange_cal = [-0.1, 20]
dmap = "afmhot"  # same as ds9 bb

run_cc_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii, fits
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-pub.stsci.edu"

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image
from helpers.miri_clean import make_sky
from helpers.miri_helpers import miri_image3

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.3.dev1+g3e8a10cb.d20220719

# %% [markdown]
# ## Make a sky and subtract it

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename_bkg}*ge_fixed_wcs_cal.fits")
subfiles = glob.glob(f"./{filter}/stage2/{basename}*ge_fixed_wcs_cal.fits")
simage = make_sky(miri_cal_files, ds9regions=ds9region, subfiles=subfiles)
# Out:
# ['./F770W/stage2/jw02107039001_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039001_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039001_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039001_02101_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00004_mirimage_fixed_wcs_cal.fits']
# processing ./F770W/stage2/jw02107040001_02201_00001_mirimage_fixed_wcs_cal.fits
# median sky = 12.189926147460938
# processing ./F770W/stage2/jw02107040001_02201_00002_mirimage_fixed_wcs_cal.fits
# median sky = 12.195058822631836
# processing ./F770W/stage2/jw02107040001_02201_00003_mirimage_fixed_wcs_cal.fits
# median sky = 12.21010684967041
# processing ./F770W/stage2/jw02107040001_02201_00004_mirimage_fixed_wcs_cal.fits
# median sky = 12.212715148925781
# processing ./F770W/stage2/jw02107040002_02201_00001_mirimage_fixed_wcs_cal.fits
# median sky = 12.175925254821777
# processing ./F770W/stage2/jw02107040002_02201_00002_mirimage_fixed_wcs_cal.fits
# median sky = 12.16848373413086
# processing ./F770W/stage2/jw02107040002_02201_00003_mirimage_fixed_wcs_cal.fits
# median sky = 12.194458961486816
# processing ./F770W/stage2/jw02107040002_02201_00004_mirimage_fixed_wcs_cal.fits
# median sky = 12.195215225219727
# Not scaling individual images to median bkg
# ./F770W/stage2/jw02107039001_02101_00001_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039001_02101_00002_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039001_02101_00003_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039001_02101_00004_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039002_02101_00001_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039002_02101_00002_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039002_02101_00003_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039002_02101_00004_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039003_02101_00001_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039003_02101_00002_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039003_02101_00003_mirimage_fixed_wcs_cal.fits
# ./F770W/stage2/jw02107039003_02101_00004_mirimage_fixed_wcs_cal.fits

# %%
show_image(simage, 12., 15., dmap=dmap)

# %% [markdown]
# ### rerun CALWEBB_IMAGE3 with the new cleaned files

# %%
if run_cc_image3:
    miri_cccal_files = glob.glob(f"./{filter}/stage2/{basename}*ge_fixed_wcs_skysub_cal.fits")
    output_dir = f"./{filter}/stage3/"
    print(miri_cccal_files)

    if rotation is not None:
        miri_asn_name = f'miri_{filter}_stage3_nirproj_asn_skysub'
    else: 
        miri_asn_name = f'miri_{filter}_stage3_asn_skysub'   
    miri_asn = asn_from_list.asn_from_list(miri_cccal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

    miri_asn_file = f'{miri_asn_name}.json'
    with open(miri_asn_file, 'w') as outfile:
        name, serialized = miri_asn.dump(format='json')
        outfile.write(serialized)
# Out:
# ['./F770W/stage2/jw02107039001_02101_00001_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039001_02101_00002_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039001_02101_00003_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039001_02101_00004_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039002_02101_00001_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039002_02101_00002_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039002_02101_00003_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039002_02101_00004_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039003_02101_00001_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039003_02101_00002_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039003_02101_00003_mirimage_fixed_wcs_skysub_cal.fits', './F770W/stage2/jw02107039003_02101_00004_mirimage_fixed_wcs_skysub_cal.fits']

# %%
if run_cc_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg,
                crval=crval, crpix=crpix, rotation=rotation, output_shape=output_shape,
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-28 10:02:38,270 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-28 10:02:38,272 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 10:02:38,273 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-28 10:02:38,277 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-28 10:02:38,278 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-28 10:02:38,282 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-28 10:02:38,283 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-28 10:02:38,287 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-28 10:02:38,288 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-28 10:02:38,293 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 10:02:38,295 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 10:02:38,299 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-28 10:02:38,300 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-28 10:02:38,517 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F770W_stage3_asn_skysub.json',).
# 2022-07-28 10:02:38,536 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F770W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-28 10:02:38,918 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02101_00001_mirimage_fixed_wcs_skysub_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-28 10:02:39,582 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-28 10:02:39,583 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-28 10:02:39,585 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 10:02:39,586 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-28 10:02:44,457 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-28 10:02:44,462 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-28 10:02:44,463 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-28 10:02:44,533 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-28 10:02:44,767 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-28 10:02:44,772 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-28 10:02:44,773 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-28 10:02:44,840 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-28 10:02:45,071 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-28 10:02:45,079 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 
- stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:39,860 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:41,371 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:42,891 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:44,408 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:45,930 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:47,485 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:49,041 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:50,575 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:52,102 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:53,611 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:55,120 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:55,816 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 10:03:56,672 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:58,215 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:03:59,767 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:01,326 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:02,888 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:04,419 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:06,004 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:07,572 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:09,110 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:10,667 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:12,199 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:13,787 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:14,530 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 10:04:15,433 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:17,036 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:18,618 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:20,183 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:21,825 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:23,387 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:24,966 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:26,489 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:28,063 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:29,605 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:31,125 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:32,672 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:33,406 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 10:04:34,289 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:35,846 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:37,451 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:39,019 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:40,560 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:42,108 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:43,701 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:45,245 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:46,786 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:48,357 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:49,916 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:51,506 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 10:04:52,270 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.176499523 15.828383654 24.141047137 15.815963797 24.167111308 15.747085617 24.202553241 15.759501254
# 2022-07-28 10:04:53,297 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F770W/stage3/miri_F770W_stage3_asn_skysub_i2d.fits
# 2022-07-28 10:04:53,299 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-28 10:04:53,576 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1188, 2399) from miri_F770W_stage3_asn_skysub_i2d.fits>,).
# 2022-07-28 10:04:53,581 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-28 10:04:53,625 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-28 10:04:53,648 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-28 10:04:53,650 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-28 10:04:53,651 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-28 10:04:53,652 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F770W
# 2022-07-28 10:04:53,653 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-28 10:04:53,780 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.38398
# 2022-07-28 10:04:54,852 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 295 sources
# 2022-07-28 10:04:55,685 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F770W/stage3/miri_F770W_stage3_asn_skysub_cat.ecsv
# 2022-07-28 10:04:55,977 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F770W/stage3/miri_F770W_stage3_asn_skysub_segm.fits
# 2022-07-28 10:04:55,980 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F770W_stage3_asn_skysub_segm.fits
# 2022-07-28 10:04:55,981 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-28 10:04:55,984 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
drange = drange_cal
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)
