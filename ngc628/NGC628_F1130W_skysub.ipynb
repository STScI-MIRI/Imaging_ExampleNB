# %% [markdown]
# ## F1130W - NGC 628 - skysub
#
# Author: Karl Gordon
#
# Last modified: 28 Jul 2022

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1130W"
fwhm = 3.3
basename = "jw02107039"
basename_bkg = "jw02107040"
exclude_above = None
ds9region = None

output_shape = None
crpix = None
crval = None
rotation = None

tweakreg = False
align_to_gaia = False

matchbkg = False

# display range for images
drange_raw = [34., 70.]
# display range for images
drange_cal = [-0.1, 20]
dmap = "afmhot"  # same as ds9 bb

run_cc_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii, fits
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-pub.stsci.edu"

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image
from helpers.miri_clean import make_sky
from helpers.miri_helpers import miri_image3

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.3.dev1+g3e8a10cb.d20220719

# %% [markdown]
# ## Make a sky and subtract it

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename_bkg}*ge_fixed_wcs_cal.fits")
subfiles = glob.glob(f"./{filter}/stage2/{basename}*ge_fixed_wcs_cal.fits")
simage = make_sky(miri_cal_files, ds9regions=ds9region, subfiles=subfiles)
# Out:
# processing ./F1130W/stage2/jw02107040001_06201_00001_mirimage_fixed_wcs_cal.fits
# median sky = 43.432037353515625
# processing ./F1130W/stage2/jw02107040001_06201_00002_mirimage_fixed_wcs_cal.fits
# median sky = 43.22962188720703
# processing ./F1130W/stage2/jw02107040001_06201_00003_mirimage_fixed_wcs_cal.fits
# median sky = 43.18083190917969
# processing ./F1130W/stage2/jw02107040001_06201_00004_mirimage_fixed_wcs_cal.fits
# median sky = 43.120460510253906
# processing ./F1130W/stage2/jw02107040002_06201_00001_mirimage_fixed_wcs_cal.fits
# median sky = 43.348148345947266
# processing ./F1130W/stage2/jw02107040002_06201_00002_mirimage_fixed_wcs_cal.fits
# median sky = 43.16880798339844
# processing ./F1130W/stage2/jw02107040002_06201_00003_mirimage_fixed_wcs_cal.fits
# median sky = 43.11101531982422
# processing ./F1130W/stage2/jw02107040002_06201_00004_mirimage_fixed_wcs_cal.fits
# median sky = 43.05836868286133
# Not scaling individual images to median bkg
# ./F1130W/stage2/jw02107039001_02105_00001_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039001_02105_00002_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039001_02105_00003_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039001_02105_00004_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039002_02105_00001_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039002_02105_00002_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039002_02105_00003_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039002_02105_00004_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039003_02105_00001_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039003_02105_00002_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039003_02105_00003_mirimage_fixed_wcs_cal.fits
# ./F1130W/stage2/jw02107039003_02105_00004_mirimage_fixed_wcs_cal.fits

# %%
show_image(simage, 42., 50., dmap=dmap)

# %% [markdown]
# ### rerun CALWEBB_IMAGE3 with the new cleaned files

# %%
if run_cc_image3:
    miri_cccal_files = glob.glob(f"./{filter}/stage2/{basename}*ge_fixed_wcs_skysub_cal.fits")
    output_dir = f"./{filter}/stage3/"
    print(miri_cccal_files)

    if rotation is not None:
        miri_asn_name = f'miri_{filter}_stage3_nirproj_asn_skysub'
    else: 
        miri_asn_name = f'miri_{filter}_stage3_asn_skysub'   
    miri_asn = asn_from_list.asn_from_list(miri_cccal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

    miri_asn_file = f'{miri_asn_name}.json'
    with open(miri_asn_file, 'w') as outfile:
        name, serialized = miri_asn.dump(format='json')
        outfile.write(serialized)
# Out:
# ['./F1130W/stage2/jw02107039001_02105_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039001_02105_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039001_02105_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039001_02105_00004_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039002_02105_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039002_02105_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039002_02105_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039002_02105_00004_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039003_02105_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039003_02105_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039003_02105_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1130W/stage2/jw02107039003_02105_00004_mirimage_fixed_wcs_skysub_cal.fits']

# %%
if run_cc_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg,
                crval=crval, crpix=crpix, rotation=rotation, output_shape=output_shape,
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-28 11:04:37,166 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-28 11:04:37,168 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:04:37,169 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-28 11:04:37,173 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-28 11:04:37,174 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-28 11:04:37,177 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-28 11:04:37,178 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-28 11:04:37,180 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-28 11:04:37,182 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-28 11:04:37,184 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 11:04:37,185 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 11:04:37,187 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-28 11:04:37,188 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-28 11:04:37,369 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1130W_stage3_asn_skysub.json',).
# 2022-07-28 11:04:37,386 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1130W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 3.3, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-28 11:04:37,720 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02105_00001_mirimage_fixed_wcs_skysub_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-28 11:04:38,516 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-28 11:04:38,517 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-28 11:04:38,518 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:04:38,519 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-28 11:04:42,781 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-28 11:04:42,787 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 3.3, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-28 11:04:42,788 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-28 11:04:42,856 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-28 11:04:43,043 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-28 11:04:43,047 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-28 11:04:43,048 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-28 11:04:43,117 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-28 11:04:43,324 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-28 11:04:43,330 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-28 11:04:43,351 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 12 inputs
# 2022-07-28 11:04:43,353 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2022-07-28 11:04:43,354 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:04:43,355 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:04:43,356 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:04:44,767 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:46,396 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:47,978 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:49,602 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:51,333 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:53,078 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:54,774 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:56,557 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:04:58,366 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:05:00,177 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:05:01,825 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:05:03,473 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:05:06,668 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 12 images
# 2022-07-28 11:05:08,975 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-28 11:05:09,985 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:11,051 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:12,198 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:13,375 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:14,540 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:15,691 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:16,826 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:18,053 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:19,259 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:20,430 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:21,592 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:22,740 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:05:22,797 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-28 11:05:22,936 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 711 (0.07%)
# 2022-07-28 11:05:23,068 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 750 (0.07%)
# 2022-07-28 11:05:23,200 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 508 (0.05%)
# 2022-07-28 11:05:23,332 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 290 (0.03%)
# 2022-07-28 11:05:23,461 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 321 (0.03%)
# 2022-07-28 11:05:23,597 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 257 (0.02%)
# 2022-07-28 11:05:23,730 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 690 (0.07%)
# 2022-07-28 11:05:23,861 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 613 (0.06%)
# 2022-07-28 11:05:23,995 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 60 (0.01%)
# 2022-07-28 11:05:24,137 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 52 (0.00%)
# 2022-07-28 11:05:24,276 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 73 (0.01%)
# 2022-07-28 11:05:24,404 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 70 (0.01%)
# 2022-07-28 11:05:25,267 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039001_02105_00001_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:25,792 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039001_02105_00002_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:26,313 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039001_02105_00003_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:26,823 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039001_02105_00004_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:27,343 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039002_02105_00001_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:27,847 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039002_02105_00002_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:28,385 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039002_02105_00003_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:28,955 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039002_02105_00004_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:29,515 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039003_02105_00001_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:30,042 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039003_02105_00002_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:30,559 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039003_02105_00003_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:31,080 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1130W/stage3/jw02107039003_02105_00004_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:05:31,081 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-07-28 11:05:31,313 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-07-28 11:05:31,318 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}
# 2022-07-28 11:05:31,357 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-28 11:05:31,419 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-07-28 11:05:31,420 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:05:31,421 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:05:31,421 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:05:31,848 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for miri_F1130W_stage3_asn_skysub
# 2022-07-28 11:05:33,615 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-07-28 11:05:34,435 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:35,895 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:37,424 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:38,966 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:40,515 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:42,023 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:43,591 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:45,085 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:46,580 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:48,086 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:49,572 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:51,075 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:51,730 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 11:05:52,555 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:54,039 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:55,522 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:57,004 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:05:58,495 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:00,020 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:01,541 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:03,023 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:04,579 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:06,093 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:07,618 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:09,197 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:09,868 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 11:06:10,693 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:12,173 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:13,656 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:15,114 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:16,600 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:18,087 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:19,577 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:21,074 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:22,550 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:23,985 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:25,462 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:27,025 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:27,807 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 11:06:28,644 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:30,276 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:31,757 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:33,209 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:34,801 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:36,283 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:37,943 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:39,524 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:41,048 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:42,502 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:44,092 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:45,545 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:06:46,280 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.176517495 15.828385258 24.141065274 15.815964962 24.167130365 15.747087105 24.202572133 15.759503180
# 2022-07-28 11:06:47,285 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1130W/stage3/miri_F1130W_stage3_asn_skysub_i2d.fits
# 2022-07-28 11:06:47,286 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-28 11:06:47,495 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1188, 2399) from miri_F1130W_stage3_asn_skysub_i2d.fits>,).
# 2022-07-28 11:06:47,499 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-28 11:06:47,535 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-28 11:06:47,553 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-28 11:06:47,555 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-28 11:06:47,556 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-28 11:06:47,557 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1130W
# 2022-07-28 11:06:47,558 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-28 11:06:47,677 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 5.49349
# 2022-07-28 11:06:48,710 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 228 sources
# 2022-07-28 11:06:49,317 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1130W/stage3/miri_F1130W_stage3_asn_skysub_cat.ecsv
# 2022-07-28 11:06:49,589 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1130W/stage3/miri_F1130W_stage3_asn_skysub_segm.fits
# 2022-07-28 11:06:49,592 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1130W_stage3_asn_skysub_segm.fits
# 2022-07-28 11:06:49,593 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-28 11:06:49,597 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
drange = drange_cal
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)
