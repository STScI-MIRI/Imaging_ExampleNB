# %% [markdown]
# ## JWST F770W NGC628 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 28 Jul 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F770W"
fwhm = 2.2
basename = "jw021070"

# rotation = 0.0
crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
tile1_shifts = [0.0, 0.0]
tile2_shifts = [0.0, 0.0]
tile3_shifts = [0.0, 0.0]
tile4_shifts = [0.0, 0.0]
tile5_shifts = [0.0, 0.0]
#tweakreg = True
#align_to_gaia = True
#tile1_shifts = [-0.05647150365601337, -0.2759964433337788]
#tile2_shifts = [0.25227164704614663, -0.31523502700888206]
#tile3_shifts = [-0.2545612377015838, -0.3166996893456614]
#tile4_shifts = [-0.257545863147537, -0.31632086761441347]
#tile5_shifts = [-0.2575264791579155, -0.3163360127396757]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [15., 350.]
# display range for calibrated images
drange_cal = [4., 200.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = False
run_image2 = False
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.3.dev1+g3e8a10cb.d20220719

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev1+g51f5dfc

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F770W/stage0/jw02107039001_02101_00001_mirimage_uncal.fits', './F770W/stage0/jw02107039001_02101_00002_mirimage_uncal.fits', './F770W/stage0/jw02107039001_02101_00003_mirimage_uncal.fits', './F770W/stage0/jw02107039001_02101_00004_mirimage_uncal.fits', './F770W/stage0/jw02107039002_02101_00001_mirimage_uncal.fits', './F770W/stage0/jw02107039002_02101_00002_mirimage_uncal.fits', './F770W/stage0/jw02107039002_02101_00003_mirimage_uncal.fits', './F770W/stage0/jw02107039002_02101_00004_mirimage_uncal.fits', './F770W/stage0/jw02107039003_02101_00001_mirimage_uncal.fits', './F770W/stage0/jw02107039003_02101_00002_mirimage_uncal.fits', './F770W/stage0/jw02107039003_02101_00003_mirimage_uncal.fits', './F770W/stage0/jw02107039003_02101_00004_mirimage_uncal.fits', './F770W/stage0/jw02107040001_02201_00001_mirimage_uncal.fits', './F770W/stage0/jw02107040001_02201_00002_mirimage_uncal.fits', './F770W/stage0/jw02107040001_02201_00003_mirimage_uncal.fits', './F770W/stage0/jw02107040001_02201_00004_mirimage_uncal.fits', './F770W/stage0/jw02107040002_02201_00001_mirimage_uncal.fits', './F770W/stage0/jw02107040002_02201_00002_mirimage_uncal.fits', './F770W/stage0/jw02107040002_02201_00003_mirimage_uncal.fits', './F770W/stage0/jw02107040002_02201_00004_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F770W/stage1/jw02107039001_02101_00001_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039001_02101_00002_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039001_02101_00003_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039001_02101_00004_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039002_02101_00001_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039002_02101_00002_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039002_02101_00003_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039002_02101_00004_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039003_02101_00001_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039003_02101_00002_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039003_02101_00003_mirimage_fixed_rate.fits', './F770W/stage1/jw02107039003_02101_00004_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040001_02201_00001_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040001_02201_00002_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040001_02201_00003_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040001_02201_00004_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040002_02201_00001_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040002_02201_00002_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040002_02201_00003_mirimage_fixed_rate.fits', './F770W/stage1/jw02107040002_02201_00004_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39001*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# update the WCS for mosaic tile 2
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39002*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile2_shifts)
    
# update the WCS for mosaic tile 3
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39003*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile3_shifts)
    
# update the WCS for mosaic tile 4
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}40001*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile4_shifts)
    
# update the WCS for mosaic tile 5
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}40002*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile5_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F770W/stage2/jw02107039001_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039001_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039001_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039001_02101_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039002_02101_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107039003_02101_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040001_02201_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040001_02201_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040001_02201_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040001_02201_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040002_02201_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040002_02201_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040002_02201_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02107040002_02201_00004_mirimage_fixed_wcs_cal.fits']
# miri_F770W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-28 10:29:10,761 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-28 10:29:10,763 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 10:29:10,764 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-28 10:29:10,767 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-28 10:29:10,768 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-28 10:29:10,771 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-28 10:29:10,772 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-28 10:29:10,775 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-28 10:29:10,776 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-28 10:29:10,778 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 10:29:10,783 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 10:29:10,788 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-28 10:29:10,790 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-28 10:29:11,129 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F770W_stage3_asn.json',).
# 2022-07-28 10:29:11,146 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F770W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-28 10:29:11,520 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02101_00001_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-28 10:29:12,161 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-28 10:29:12,163 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-28 10:29:12,164 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 10:29:12,165 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-28 10:29:19,676 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-28 10:29:19,681 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-28 10:29:19,683 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-28 10:29:19,785 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-28 10:29:20,123 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-28 10:29:20,128 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-28 10:29:20,129 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-28 10:29:20,223 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-28 10:29:20,561 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-28 10:29:20,567 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-28 10:29:20,587 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2022-07-28 10:29:20,589 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2022-07-28 10:29:20,590 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 10:29:20,591 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2022-07-28 10:29:20,592 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2022-07-28 10:29:22,269 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:24,101 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:25,875 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:27,738 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:29,428 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:31,131 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:32,870 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:34,528 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:36,145 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:37,770 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:39,509 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:41,211 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:42,848 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:44,498 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:46,144 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:47,790 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:49,431 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:51,072 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:52,755 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:29:54,410 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 10:30:05,029 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 20 images
# 2022-07-28 10:30:45,924 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-28 10:30:47,202 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:48,699 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:49,835 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:50,980 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:52,134 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:53,374 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:54,646 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:56,086 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:57,793 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:30:59,539 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:01,218 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:02,858 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:04,517 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:05,966 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:07,502 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:09,262 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:10,743 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:12,208 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:14,242 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:15,789 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 10:31:15,854 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-28 10:31:16,038 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1244 (0.12%)
# 2022-07-28 10:31:16,207 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1346 (0.13%)
# 2022-07-28 10:31:16,381 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 764 (0.07%)
# 2022-07-28 10:31:16,550 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 466 (0.04%)
# 2022-07-28 10:31:16,724 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 490 (0.05%)
# 2022-07-28 10:31:16,890 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 420 (0.04%)
# 2022-07-28 10:31:17,057 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1435 (0.14%)
# 2022-07-28 10:31:17,225 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1246 (0.12%)
# 2022-07-28 10:31:17,392 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 342 (0.03%)
# 2022-07-28 10:31:17,558 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 274 (0.03%)
# 2022-07-28 10:31:17,723 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 323 (0.03%)
# 2022-07-28 10:31:17,898 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 359 (0.03%)
# 2022-07-28 10:31:18,066 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 135 (0.01%)
# 2022-07-28 10:31:18,235 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 362 (0.03%)
# 2022-07-28 10:31:18,405 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 521 (0.05%)
# 2022-07-28 10:31:18,571 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 400 (0.04%)
# 2022-07-28 10:31:18,737 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 114 (0.01%)
# 2022-07-28 10:31:18,902 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 372 (0.04%)
# 2022-07-28 10:31:19,068 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 528 (0.05%)
# 2022-07-28 10:31:19,243 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 375 (0.04%)
# 2022-07-28 10:31:20,035 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039001_02101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:20,680 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039001_02101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:21,186 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039001_02101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:21,742 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039001_02101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:22,315 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039002_02101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:22,885 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039002_02101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:23,468 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039002_02101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:24,007 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039002_02101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:24,582 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039003_02101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:25,144 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039003_02101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:25,714 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039003_02101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:26,232 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107039003_02101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:26,756 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040001_02201_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:27,281 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040001_02201_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:27,858 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040001_02201_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:28,464 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040001_02201_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:29,042 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040002_02201_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:29,582 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040002_02201_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:30,134 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040002_02201_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:30,712 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02107040002_02201_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 10:31:30,714 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-07-28 10:31:31,208 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-07-28 10:31:31,212 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}
# 2022-07-28 10:31:31,262 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-28 10:31:31,337 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-07-28 10:31:31,338 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 10:31:31,339 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-07-28 10:31:31,339 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-07-28 10:31:32,008 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for miri_F770W_stage3_asn
# 2022-07-28 10:31:34,032 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-07-28 10:31:34,855 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:36,477 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:38,065 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:39,926 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:41,667 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:43,290 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:44,988 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:46,590 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:48,214 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:50,022 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:52,010 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:54,088 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:56,569 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:31:59,015 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:01,348 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:03,637 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:05,951 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:07,577 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:09,578 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:11,132 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:11,815 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 10:32:12,751 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:14,547 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:16,475 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:18,378 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:20,146 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:21,818 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:23,464 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:25,053 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:26,737 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:28,448 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:30,218 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:31,911 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:33,474 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:35,150 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:37,023 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:39,362 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:41,885 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:43,692 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:45,278 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:46,980 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:47,879 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 10:32:49,079 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:51,197 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:53,172 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:54,999 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:56,681 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:32:58,816 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:00,567 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:02,164 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:03,846 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:05,555 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:07,151 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:08,887 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:10,478 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:12,049 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:13,644 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:15,288 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:16,932 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:18,639 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:20,290 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:21,955 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:22,813 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 10:33:23,756 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:25,555 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:27,304 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:29,035 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:30,807 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:32,575 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:34,475 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:37,092 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:39,725 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:41,444 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:43,079 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:44,775 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:46,469 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:48,113 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:50,081 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:51,752 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:53,751 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:56,299 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:33:58,720 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:34:01,281 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 10:34:02,759 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.176498944 15.828383539 24.113535618 15.806319728 24.175413607 15.642784550 24.238333017 15.664830623
# 2022-07-28 10:34:04,921 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F770W/stage3/miri_F770W_stage3_asn_i2d.fits
# 2022-07-28 10:34:04,922 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-28 10:34:05,324 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(2110, 5696) from miri_F770W_stage3_asn_i2d.fits>,).
# 2022-07-28 10:34:05,329 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-28 10:34:05,386 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-28 10:34:05,417 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-28 10:34:05,418 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-28 10:34:05,419 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-28 10:34:05,420 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F770W
# 2022-07-28 10:34:05,421 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-28 10:34:05,588 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.38398
# 2022-07-28 10:34:09,714 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 295 sources
# 2022-07-28 10:34:10,867 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F770W/stage3/miri_F770W_stage3_asn_cat.ecsv
# 2022-07-28 10:34:11,195 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F770W/stage3/miri_F770W_stage3_asn_segm.fits
# 2022-07-28 10:34:11,198 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F770W_stage3_asn_segm.fits
# 2022-07-28 10:34:11,207 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-28 10:34:11,211 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
