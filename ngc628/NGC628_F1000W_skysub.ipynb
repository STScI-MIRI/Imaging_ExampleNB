# %% [markdown]
# ## F1000W - NGC 628 - skysub
#
# Author: Karl Gordon
#
# Last modified: 28 Jul 2022

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1000W"
fwhm = 2.9
basename = "jw02107039"
basename_bkg = "jw02107040"
exclude_above = None
ds9region = None

output_shape = None
crpix = None
crval = None
rotation = None

tweakreg = False
align_to_gaia = False

matchbkg = False

# display range for images
drange_cal = [-0.1, 20]
dmap = "afmhot"  # same as ds9 bb

run_cc_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii, fits
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-pub.stsci.edu"

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image
from helpers.miri_clean import make_sky
from helpers.miri_helpers import miri_image3

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.3.dev1+g3e8a10cb.d20220719

# %% [markdown]
# ## Make a sky and subtract it

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename_bkg}*ge_fixed_wcs_cal.fits")
subfiles = glob.glob(f"./{filter}/stage2/{basename}*ge_fixed_wcs_cal.fits")
simage = make_sky(miri_cal_files, ds9regions=ds9region, subfiles=subfiles)
# Out:
# processing ./F1000W/stage2/jw02107040001_04201_00001_mirimage_fixed_wcs_cal.fits
# median sky = 30.077224731445312
# processing ./F1000W/stage2/jw02107040001_04201_00002_mirimage_fixed_wcs_cal.fits
# median sky = 30.150466918945312
# processing ./F1000W/stage2/jw02107040001_04201_00003_mirimage_fixed_wcs_cal.fits
# median sky = 30.181419372558594
# processing ./F1000W/stage2/jw02107040001_04201_00004_mirimage_fixed_wcs_cal.fits
# median sky = 30.185043334960938
# processing ./F1000W/stage2/jw02107040002_04201_00001_mirimage_fixed_wcs_cal.fits
# median sky = 30.020854949951172
# processing ./F1000W/stage2/jw02107040002_04201_00002_mirimage_fixed_wcs_cal.fits
# median sky = 30.109586715698242
# processing ./F1000W/stage2/jw02107040002_04201_00003_mirimage_fixed_wcs_cal.fits
# median sky = 30.12103843688965
# processing ./F1000W/stage2/jw02107040002_04201_00004_mirimage_fixed_wcs_cal.fits
# median sky = 30.13389015197754
# Not scaling individual images to median bkg
# ./F1000W/stage2/jw02107039001_02103_00001_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039001_02103_00002_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039001_02103_00003_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039001_02103_00004_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039002_02103_00001_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039002_02103_00002_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039002_02103_00003_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039002_02103_00004_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039003_02103_00001_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039003_02103_00002_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039003_02103_00003_mirimage_fixed_wcs_cal.fits
# ./F1000W/stage2/jw02107039003_02103_00004_mirimage_fixed_wcs_cal.fits

# %%
show_image(simage, 30, 40., dmap=dmap)

# %% [markdown]
# ### rerun CALWEBB_IMAGE3 with the new cleaned files

# %%
if run_cc_image3:
    miri_cccal_files = glob.glob(f"./{filter}/stage2/{basename}*ge_fixed_wcs_skysub_cal.fits")
    output_dir = f"./{filter}/stage3/"
    print(miri_cccal_files)

    if rotation is not None:
        miri_asn_name = f'miri_{filter}_stage3_nirproj_asn_skysub'
    else: 
        miri_asn_name = f'miri_{filter}_stage3_asn_skysub'   
    miri_asn = asn_from_list.asn_from_list(miri_cccal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

    miri_asn_file = f'{miri_asn_name}.json'
    with open(miri_asn_file, 'w') as outfile:
        name, serialized = miri_asn.dump(format='json')
        outfile.write(serialized)
# Out:
# ['./F1000W/stage2/jw02107039001_02103_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039001_02103_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039001_02103_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039001_02103_00004_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039002_02103_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039002_02103_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039002_02103_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039002_02103_00004_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039003_02103_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039003_02103_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039003_02103_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1000W/stage2/jw02107039003_02103_00004_mirimage_fixed_wcs_skysub_cal.fits']

# %%
if run_cc_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg,
                crval=crval, crpix=crpix, rotation=rotation, output_shape=output_shape,
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-28 11:55:46,262 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-28 11:55:46,265 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:55:46,267 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-28 11:55:46,271 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-28 11:55:46,272 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-28 11:55:46,276 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-28 11:55:46,277 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-28 11:55:46,280 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-28 11:55:46,282 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-28 11:55:46,285 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 11:55:46,286 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 11:55:46,289 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-28 11:55:46,290 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-28 11:55:46,526 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1000W_stage3_asn_skysub.json',).
# 2022-07-28 11:55:46,544 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-28 11:55:46,868 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00001_mirimage_fixed_wcs_skysub_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-28 11:55:47,451 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-28 11:55:47,452 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-28 11:55:47,453 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:55:47,454 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-28 11:55:51,938 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-28 11:55:51,943 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-28 11:55:51,944 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-28 11:55:52,017 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-28 11:55:52,292 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-28 11:55:52,296 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-28 11:55:52,297 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-28 11:55:52,361 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-28 11:55:52,595 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-28 11:55:52,599 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-28 11:55:52,617 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 12 inputs
# 2022-07-28 11:55:52,619 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2022-07-28 11:55:52,620 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:55:52,621 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:55:52,622 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:55:54,137 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:55:56,083 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:55:58,106 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:55:59,730 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:01,353 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:03,080 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:04,911 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:06,631 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:08,316 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:10,006 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:11,702 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:13,400 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1178, 2379)
# 2022-07-28 11:56:16,528 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 12 images
# 2022-07-28 11:56:18,999 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-28 11:56:20,030 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:21,112 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:22,228 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:23,415 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:24,630 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:25,864 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:27,055 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:28,271 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:29,480 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:30,674 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:31,832 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:33,015 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1178, 2379)
# 2022-07-28 11:56:33,069 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-28 11:56:33,218 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 173 (0.02%)
# 2022-07-28 11:56:33,356 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 309 (0.03%)
# 2022-07-28 11:56:33,480 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 113 (0.01%)
# 2022-07-28 11:56:33,612 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 122 (0.01%)
# 2022-07-28 11:56:33,741 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 171 (0.02%)
# 2022-07-28 11:56:33,869 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 151 (0.01%)
# 2022-07-28 11:56:33,993 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 369 (0.03%)
# 2022-07-28 11:56:34,122 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 429 (0.04%)
# 2022-07-28 11:56:34,260 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 31 (0.00%)
# 2022-07-28 11:56:34,390 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 20 (0.00%)
# 2022-07-28 11:56:34,520 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 30 (0.00%)
# 2022-07-28 11:56:34,650 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 27 (0.00%)
# 2022-07-28 11:56:35,260 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00001_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:35,875 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00002_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:36,429 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00003_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:37,103 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00004_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:37,686 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00001_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:38,465 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00002_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:39,380 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00003_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:40,002 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00004_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:40,647 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00001_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:41,256 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00002_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:41,809 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00003_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:42,331 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00004_mirimage_fixed_wcs_skysub_a3001_crf.fits
# 2022-07-28 11:56:42,332 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-07-28 11:56:42,626 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-07-28 11:56:42,630 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}
# 2022-07-28 11:56:42,676 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-28 11:56:42,740 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-07-28 11:56:42,740 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:56:42,741 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:56:42,742 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:56:43,231 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for miri_F1000W_stage3_asn_skysub
# 2022-07-28 11:56:45,137 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-07-28 11:56:45,971 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:47,513 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:49,097 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:50,598 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:52,122 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:53,620 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:55,201 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:56,731 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:58,332 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:56:59,919 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:01,397 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:02,962 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:03,647 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 11:57:04,489 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:05,991 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:07,528 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:09,027 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:10,514 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:12,034 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:13,564 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:15,083 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:16,609 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:18,159 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:19,692 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:21,238 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:21,929 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 11:57:22,851 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:24,392 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:25,901 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:27,438 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:28,948 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:30,514 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:32,263 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:33,864 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:35,486 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:37,093 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:38,635 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:40,192 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:40,922 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 11:57:41,733 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:43,195 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:44,682 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:46,165 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:47,633 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:49,117 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:50,619 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:52,093 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:53,611 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:55,154 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:56,675 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:58,171 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1188, 2399)
# 2022-07-28 11:57:58,894 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.176515356 15.828393826 24.141063135 15.815973526 24.167128235 15.747095672 24.202570003 15.759511750
# 2022-07-28 11:57:59,859 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_skysub_i2d.fits
# 2022-07-28 11:57:59,860 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-28 11:58:00,180 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1188, 2399) from miri_F1000W_stage3_asn_skysub_i2d.fits>,).
# 2022-07-28 11:58:00,184 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-28 11:58:00,225 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-28 11:58:00,246 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-28 11:58:00,248 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-28 11:58:00,249 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-28 11:58:00,249 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1000W
# 2022-07-28 11:58:00,250 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-28 11:58:00,366 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.95551
# 2022-07-28 11:58:01,443 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 228 sources
# 2022-07-28 11:58:02,153 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1000W/stage3/miri_F1000W_stage3_asn_skysub_cat.ecsv
# 2022-07-28 11:58:02,455 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_skysub_segm.fits
# 2022-07-28 11:58:02,459 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1000W_stage3_asn_skysub_segm.fits
# 2022-07-28 11:58:02,460 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-28 11:58:02,464 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
drange = drange_cal
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)
