# %% [markdown]
# ## JWST F1000W NGC628 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 28 Jul 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1000W"
fwhm = 2.9
basename = "jw021070"

# rotation = 0.0
crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
tile1_shifts = [0.0, 0.0]
tile2_shifts = [0.0, 0.0]
tile3_shifts = [0.0, 0.0]
tile4_shifts = [0.0, 0.0]
tile5_shifts = [0.0, 0.0]
#tweakreg = True
#align_to_gaia = True
#tile1_shifts = [-0.05647150365601337, -0.2759964433337788]
#tile2_shifts = [0.25227164704614663, -0.31523502700888206]
#tile3_shifts = [-0.2545612377015838, -0.3166996893456614]
#tile4_shifts = [-0.257545863147537, -0.31632086761441347]
#tile5_shifts = [-0.2575264791579155, -0.3163360127396757]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [20, 60.]
# display range for calibrated images
drange_cal = [32., 60.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = True
run_image2 = True
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.3.dev1+g3e8a10cb.d20220719

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev1+g51f5dfc

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F1000W/stage0/jw02107039001_02103_00001_mirimage_uncal.fits', './F1000W/stage0/jw02107039001_02103_00002_mirimage_uncal.fits', './F1000W/stage0/jw02107039001_02103_00003_mirimage_uncal.fits', './F1000W/stage0/jw02107039001_02103_00004_mirimage_uncal.fits', './F1000W/stage0/jw02107039002_02103_00001_mirimage_uncal.fits', './F1000W/stage0/jw02107039002_02103_00002_mirimage_uncal.fits', './F1000W/stage0/jw02107039002_02103_00003_mirimage_uncal.fits', './F1000W/stage0/jw02107039002_02103_00004_mirimage_uncal.fits', './F1000W/stage0/jw02107039003_02103_00001_mirimage_uncal.fits', './F1000W/stage0/jw02107039003_02103_00002_mirimage_uncal.fits', './F1000W/stage0/jw02107039003_02103_00003_mirimage_uncal.fits', './F1000W/stage0/jw02107039003_02103_00004_mirimage_uncal.fits', './F1000W/stage0/jw02107040001_04201_00001_mirimage_uncal.fits', './F1000W/stage0/jw02107040001_04201_00002_mirimage_uncal.fits', './F1000W/stage0/jw02107040001_04201_00003_mirimage_uncal.fits', './F1000W/stage0/jw02107040001_04201_00004_mirimage_uncal.fits', './F1000W/stage0/jw02107040002_04201_00001_mirimage_uncal.fits', './F1000W/stage0/jw02107040002_04201_00002_mirimage_uncal.fits', './F1000W/stage0/jw02107040002_04201_00003_mirimage_uncal.fits', './F1000W/stage0/jw02107040002_04201_00004_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)
# Out:
# 2022-07-28 11:37:11,917 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-28 11:37:11,919 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,920 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-28 11:37:11,923 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,924 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-28 11:37:11,927 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,929 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-28 11:37:11,932 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,934 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-28 11:37:11,936 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,937 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-07-28 11:37:11,940 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,941 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-07-28 11:37:11,943 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,944 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-07-28 11:37:11,946 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,947 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-07-28 11:37:11,949 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,950 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-07-28 11:37:11,952 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,953 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-07-28 11:37:11,955 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,956 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-07-28 11:37:11,958 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,959 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-07-28 11:37:11,962 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,963 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-07-28 11:37:11,966 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,967 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-07-28 11:37:11,970 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'none', 'override_readnoise': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,970 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-07-28 11:37:11,978 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:37:11,980 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-07-28 11:37:12,081 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('./F1000W/stage0/jw02107039001_02103_00001_mirimage_uncal.fits',).
# ./F1000W/stage0/jw02107039001_02103_00001_mirimage_uncal.fits
# 2022-07-28 11:37:12,105 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_ ...
# 2022-07-28 11:37:14,310 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00001_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2022-07-28 11:37:15,125 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits'.
# 2022-07-28 11:37:15,126 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2022-07-28 11:37:15,128 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_ipc_0009.fits'.
# 2022-07-28 11:37:15,129 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0032.fits'.
# 2022-07-28 11:37:15,130 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_mask_0030.fits'.
# 2022-07-28 11:37:15,132 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2022-07-28 11:37:15,133 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits'.
# 2022-07-28 11:37:15,135 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2022-07-28 11:37:15,135 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0070.fits'.
# 2022-07-28 11:37:15,136 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits'.
# 2022-07-28 11:37:15,137 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_saturation_0027.fits'.
# 2022-07-28 11:37:15,139 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2022-07-28 11:37:15,140 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2022-07-28 11:37:15,141 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2022-07-28 11:37:15,142 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-07-28 11:37:15,750 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:15,753 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:15,878 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-07-28 11:37:15,879 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-07-28 11:37:15,885 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-07-28 11:37:16,016 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:16,019 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:16,070 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_mask_0030.fits
# 2022-07-28 11:37:16,447 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-07-28 11:37:16,572 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:16,575 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'n_pix_grow_sat': 1}
# 2022-07-28 11:37:16,626 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_saturation_0027.fits
# 2022-07-28 11:37:17,652 - stpipe.Detector1Pipeline.saturation - INFO - Detected 2024 saturated pixels
# 2022-07-28 11:37:17,664 - stpipe.Detector1Pipeline.saturation - INFO - Detected 66 A/D floor pixels
# 2022-07-28 11:37:17,679 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-07-28 11:37:17,807 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:17,810 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:17,861 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_ipc_0009.fits
# 2022-07-28 11:37:18,248 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-07-28 11:37:18,375 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:18,378 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:18,517 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2022-07-28 11:37:18,638 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:18,641 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:18,761 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2022-07-28 11:37:18,888 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:18,891 - stpipe.Detector1Pipeline.reset - INFO - Step reset parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:18,958 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0070.fits
# 2022-07-28 11:37:19,639 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2022-07-28 11:37:19,760 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:19,763 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:19,816 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2022-07-28 11:37:20,428 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-07-28 11:37:20,558 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:20,562 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'type': 'baseline'}
# 2022-07-28 11:37:20,613 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2022-07-28 11:37:20,812 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2022-07-28 11:37:20,940 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:20,943 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'dark_output': None}
# 2022-07-28 11:37:20,994 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits
# 2022-07-28 11:37:24,794 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=11, nframes=1, groupgap=0
# 2022-07-28 11:37:24,795 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-07-28 11:37:26,077 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-07-28 11:37:26,228 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:26,231 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-07-28 11:37:26,351 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-07-28 11:37:26,352 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-07-28 11:37:26,353 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-07-28 11:37:26,354 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-07-28 11:37:26,355 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-07-28 11:37:26,355 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-07-28 11:37:26,356 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-07-28 11:37:26,357 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-07-28 11:37:26,358 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-07-28 11:37:26,530 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-07-28 11:37:26,559 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-07-28 11:37:26,691 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:26,695 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-07-28 11:37:26,721 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-07-28 11:37:26,722 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-07-28 11:37:26,750 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:37:26,823 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:37:27,017 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-07-28 11:37:27,037 - stpipe.Detector1Pipeline.jump - INFO - Creating 4 processes for jump detection
# 2022-07-28 11:37:27,210 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:37:27,296 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:37:27,388 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:37:27,481 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:37:27,595 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:37:27,615 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4307 pixels with at least one CR from five or more groups.
# 2022-07-28 11:37:27,617 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 17 pixels with at least one CR from four groups.
# 2022-07-28 11:37:27,618 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 11 pixels with at least one CR from three groups.
# 2022-07-28 11:37:27,651 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:37:27,667 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2802 pixels with at least one CR from five or more groups.
# 2022-07-28 11:37:27,668 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2 pixels with at least one CR from four groups.
# 2022-07-28 11:37:27,669 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8 pixels with at least one CR from three groups.
# 2022-07-28 11:37:27,751 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:37:27,772 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2922 pixels with at least one CR from five or more groups.
# 2022-07-28 11:37:27,774 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2 pixels with at least one CR from four groups.
# 2022-07-28 11:37:27,775 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2 pixels with at least one CR from three groups.
# 2022-07-28 11:37:27,870 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:37:27,890 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3598 pixels with at least one CR from five or more groups.
# 2022-07-28 11:37:27,892 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 25 pixels with at least one CR from four groups.
# 2022-07-28 11:37:27,894 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 15 pixels with at least one CR from three groups.
# 2022-07-28 11:37:30,428 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 3.40969 sec
# 2022-07-28 11:37:30,438 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 3.717052
# 2022-07-28 11:37:30,451 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-07-28 11:37:30,605 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 11, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:30,609 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-07-28 11:37:30,688 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:37:30,689 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:37:30,786 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-07-28 11:37:30,787 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-07-28 11:37:30,905 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2022-07-28 11:37:30,907 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2022-07-28 11:37:30,908 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 4
# 2022-07-28 11:37:35,301 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:37:35,307 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:37:35,370 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:37:35,375 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:37:35,605 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:37:35,609 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:37:35,731 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:37:35,734 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:37:36,007 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-07-28 11:37:36,158 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:36,161 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:36,247 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:37:36,248 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:37:36,258 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:37:36,378 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 1024, 1032) from jw02107039001_02103_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:37:36,382 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:37:36,488 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:37:36,489 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:37:36,499 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:37:36,698 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1000W/stage1/jw02107039001_02103_00001_mirimage_rateints.fits
# 2022-07-28 11:37:36,699 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-07-28 11:37:36,700 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:37:36,868 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1000W/stage1/jw02107039001_02103_00001_mirimage_rate.fits
# 2022-07-28 11:37:36,869 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-07-28 11:37:36,888 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-28 11:37:36,890 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,891 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-28 11:37:36,893 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,894 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-28 11:37:36,896 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,898 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-28 11:37:36,900 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,901 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-28 11:37:36,902 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,905 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-07-28 11:37:36,907 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,909 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-07-28 11:37:36,911 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,912 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-07-28 11:37:36,914 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,915 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-07-28 11:37:36,917 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,918 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-07-28 11:37:36,921 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,921 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-07-28 11:37:36,923 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,924 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-07-28 11:37:36,926 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,927 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-07-28 11:37:36,929 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
# 2022-07-28 11:37:36,930 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-07-28 11:37:36,932 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,934 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-07-28 11:37:36,936 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'none', 'override_readnoise': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,937 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-07-28 11:37:36,939 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:37:36,940 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-07-28 11:37:37,063 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('./F1000W/stage0/jw02107039001_02103_00002_mirimage_uncal.fits',).
# 2022-07-28 11:37:37,086 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_ ...
# ./F1000W/stage0/jw02107039001_02103_00002_mirimage_uncal.fits
# 2022-07-28 11:37:37,589 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00002_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2022-07-28 11:37:37,596 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits'.
# 2022-07-28 11:37:37,598 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2022-07-28 11:37:37,599 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_ipc_0009.fits'.
# 2022-07-28 11:37:37,599 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0032.fits'.
# ...
# 2022-07-28 11:44:15,900 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2022-07-28 11:44:16,063 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:16,067 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:44:16,185 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2022-07-28 11:44:16,336 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:16,339 - stpipe.Detector1Pipeline.reset - INFO - Step reset parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:44:16,393 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0070.fits
# 2022-07-28 11:44:16,904 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2022-07-28 11:44:17,073 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:17,076 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:44:17,129 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2022-07-28 11:44:17,701 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-07-28 11:44:17,881 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:17,885 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'type': 'baseline'}
# 2022-07-28 11:44:17,938 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2022-07-28 11:44:18,141 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2022-07-28 11:44:18,311 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:18,314 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'dark_output': None}
# 2022-07-28 11:44:18,367 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits
# 2022-07-28 11:44:20,978 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=11, nframes=1, groupgap=0
# 2022-07-28 11:44:20,979 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-07-28 11:44:22,308 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-07-28 11:44:22,502 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:22,506 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-07-28 11:44:22,634 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-07-28 11:44:22,635 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-07-28 11:44:22,636 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-07-28 11:44:22,637 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-07-28 11:44:22,637 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-07-28 11:44:22,638 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-07-28 11:44:22,639 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-07-28 11:44:22,640 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-07-28 11:44:22,641 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-07-28 11:44:22,825 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-07-28 11:44:22,856 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-07-28 11:44:23,020 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:23,024 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-07-28 11:44:23,054 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-07-28 11:44:23,055 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-07-28 11:44:23,086 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:44:23,163 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:44:23,362 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-07-28 11:44:23,379 - stpipe.Detector1Pipeline.jump - INFO - Creating 4 processes for jump detection
# 2022-07-28 11:44:23,662 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:44:23,763 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:44:23,860 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:44:23,962 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:44:24,054 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:44:24,070 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3917 pixels with at least one CR from five or more groups.
# 2022-07-28 11:44:24,071 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 31 pixels with at least one CR from four groups.
# 2022-07-28 11:44:24,073 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 10 pixels with at least one CR from three groups.
# 2022-07-28 11:44:24,154 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:44:24,169 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2163 pixels with at least one CR from five or more groups.
# 2022-07-28 11:44:24,172 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-07-28 11:44:24,174 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2 pixels with at least one CR from three groups.
# 2022-07-28 11:44:24,276 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:44:24,295 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2634 pixels with at least one CR from five or more groups.
# 2022-07-28 11:44:24,297 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 5 pixels with at least one CR from four groups.
# 2022-07-28 11:44:24,301 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from three groups.
# 2022-07-28 11:44:24,407 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:44:24,424 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3886 pixels with at least one CR from five or more groups.
# 2022-07-28 11:44:24,426 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 22 pixels with at least one CR from four groups.
# 2022-07-28 11:44:24,428 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 19 pixels with at least one CR from three groups.
# 2022-07-28 11:44:27,430 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 4.0664 sec
# 2022-07-28 11:44:27,439 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 4.385304
# 2022-07-28 11:44:27,453 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-07-28 11:44:27,650 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 11, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:27,653 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-07-28 11:44:27,745 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:44:27,746 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:44:27,861 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-07-28 11:44:27,862 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-07-28 11:44:27,980 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2022-07-28 11:44:27,981 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2022-07-28 11:44:27,982 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 4
# 2022-07-28 11:44:32,343 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:44:32,347 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:44:32,489 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:44:32,492 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:44:32,537 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:44:32,542 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:44:32,712 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 9
# 2022-07-28 11:44:32,716 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 1
# 2022-07-28 11:44:33,021 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-07-28 11:44:33,214 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:33,218 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:44:33,310 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:44:33,311 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:44:33,323 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:44:33,489 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 1024, 1032) from jw02107040002_04201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:44:33,492 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-07-28 11:44:33,589 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:44:33,591 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:44:33,602 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:44:33,789 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1000W/stage1/jw02107040002_04201_00004_mirimage_rateints.fits
# 2022-07-28 11:44:33,790 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-07-28 11:44:33,791 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:44:33,956 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1000W/stage1/jw02107040002_04201_00004_mirimage_rate.fits
# 2022-07-28 11:44:33,957 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F1000W/stage1/jw02107039001_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039001_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039001_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039001_02103_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00004_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)
# Out:
# 2022-07-28 11:44:53,011 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2022-07-28 11:44:53,014 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None, 'override_wfssbkg': None, 'override_wavelengthrange': None, 'class': ''}
#
#
# 2022-07-28 11:44:53,015 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-07-28 11:44:53,017 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55, 'override_distortion': None, 'override_filteroffset': None, 'override_specwcs': None, 'override_regions': None, 'override_wavelengthrange': None, 'override_camera': None, 'override_collimator': None, 'override_disperser': None, 'override_fore': None, 'override_fpa': None, 'override_msa': None, 'override_ote': None, 'override_ifupost': None, 'override_ifufore': None, 'override_ifuslicer': None, 'class': ''}
#
#
# 2022-07-28 11:44:53,019 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-07-28 11:44:53,021 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False, 'override_flat': None, 'override_fflat': None, 'override_sflat': None, 'override_dflat': None, 'class': ''}
#
#
# 2022-07-28 11:44:53,022 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-07-28 11:44:53,024 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'inverse': False, 'source_type': None, 'override_photom': None, 'override_area': None, 'class': ''}
#
#
# 2022-07-28 11:44:53,025 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-07-28 11:44:53,028 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 11:44:53,029 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 11:44:53,250 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args (['./F1000W/stage1/jw02107039001_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039001_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039001_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039001_02103_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039002_02103_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107039003_02103_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040001_04201_00004_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02107040002_04201_00004_mirimage_fixed_rate.fits'],).
# 2022-07-28 11:44:53,261 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage2', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# 2022-07-28 11:44:55,131 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:55,164 - CRDS - INFO -  Fetching  /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits   21.2 M bytes  (1 / 1 files) (0 / 21.2 M bytes)
# 2022-07-28 11:44:57,413 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,414 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,415 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,416 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,417 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,418 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,419 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,420 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,421 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,422 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,423 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,423 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,424 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,425 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,426 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,426 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,427 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,427 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,429 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,430 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,431 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,432 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,432 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,434 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00002_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,448 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,449 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,450 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,451 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,451 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,452 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,453 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,455 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,455 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,456 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,457 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,458 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,458 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,459 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,460 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,460 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,461 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,461 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,463 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,464 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,464 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,465 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,466 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,467 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00003_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,474 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,475 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,476 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,476 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,477 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,477 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,479 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,479 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,480 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,481 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,482 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,482 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,483 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,483 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,484 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,485 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,485 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,486 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,487 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,487 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,488 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,488 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,489 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,490 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00004_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,497 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,498 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,498 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,499 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,500 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,500 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,501 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,502 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,503 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,504 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,505 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,505 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,506 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,506 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,507 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,508 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,508 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,509 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,510 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,510 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,511 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,511 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,512 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,513 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039002_02103_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,520 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,520 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,521 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,521 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,522 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,523 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,525 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,525 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,526 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,527 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,528 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,529 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,529 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,530 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,531 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,531 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,532 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,532 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,534 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,535 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,535 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,536 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,537 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,539 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039002_02103_00002_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,547 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,547 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,548 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,549 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,550 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,550 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,552 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,553 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,554 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,556 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,557 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,557 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,558 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,559 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,559 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,560 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,561 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,561 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,564 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,565 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,565 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,566 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,567 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,569 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039002_02103_00003_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,576 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,577 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,578 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,579 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,579 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,580 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,581 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,581 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,582 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,583 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,583 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,584 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,584 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,585 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,585 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,586 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,586 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,587 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,588 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,589 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,589 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,590 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,591 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,593 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039002_02103_00004_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,604 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,605 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,606 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,607 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,607 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,608 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,609 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,609 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,610 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,611 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,611 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,612 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,612 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,613 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,614 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,614 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,615 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,615 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,617 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,618 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,618 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,619 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,619 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,621 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039003_02103_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,629 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,630 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,630 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,631 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,631 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,632 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,633 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,634 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,635 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,636 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,637 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,637 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,638 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,638 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,639 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,639 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,640 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,640 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,642 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,642 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,643 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,644 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,644 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,645 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039003_02103_00002_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,653 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,654 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,655 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,655 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,656 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,656 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,658 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,658 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,659 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,660 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,661 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,661 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,662 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,662 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,663 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,663 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,664 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,664 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,666 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,667 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,667 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,668 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,668 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,669 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039003_02103_00003_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,678 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,679 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,680 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,680 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,681 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,681 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,683 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,683 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,684 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,684 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,685 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,686 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,686 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,687 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,688 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,688 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,689 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,690 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,691 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,692 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,692 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,693 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,694 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,696 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039003_02103_00004_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,706 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,707 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,708 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,708 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,709 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,709 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,711 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,712 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,712 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,713 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,714 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,715 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,715 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-07-28 11:44:57,716 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-07-28 11:44:57,717 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-07-28 11:44:57,718 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-07-28 11:44:57,719 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-07-28 11:44:57,721 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-07-28 11:44:57,722 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-07-28 11:44:57,722 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,723 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-07-28 11:44:57,724 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-07-28 11:44:57,725 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-07-28 11:44:57,726 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107040001_04201_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11:44:57,739 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-07-28 11:44:57,741 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-07-28 11:44:57,742 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-07-28 11:44:57,743 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,743 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-07-28 11:44:57,745 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-07-28 11:44:57,746 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:44:57,747 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-07-28 11:44:57,750 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-07-28 11:44:57,751 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-07-28 11:44:57,753 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-07-28 11:44:57,754 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-07-28 11:44:57,754 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# ...
# 2022-07-28 11:47:39,649 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2022-07-28 11:47:39,653 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2022-07-28 11:47:39,654 - stpipe.Image2Pipeline.photom - WARNING - Expected to find one matching row in table, found 0.
# 2022-07-28 11:47:39,656 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 0.369118
# 2022-07-28 11:47:39,692 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2022-07-28 11:47:40,027 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from jw02107040002_04201_00003_mirimage_fixed_rate.fits>,).
# 2022-07-28 11:47:40,034 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': False, 'allowed_memory': None}
# 2022-07-28 11:47:40,098 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-28 11:47:40,138 - stpipe.Image2Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-07-28 11:47:40,139 - stpipe.Image2Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:47:40,140 - stpipe.Image2Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:47:40,141 - stpipe.Image2Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:47:40,371 - stpipe.Image2Pipeline.resample - INFO - Resampling science data
# 2022-07-28 11:47:41,044 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:41,739 - stpipe.Image2Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 11:47:42,501 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:43,144 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 11:47:43,842 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:44,489 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 11:47:45,169 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:45,877 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.185181838 15.717208675 24.154102294 15.707681498 24.164097004 15.677470180 24.195172410 15.686995945
# 2022-07-28 11:47:46,122 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./F1000W/stage2/jw02107040002_04201_00003_mirimage_fixed_i2d.fits
# 2022-07-28 11:47:46,124 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2022-07-28 11:47:46,125 - stpipe.Image2Pipeline - INFO - Finished processing product ./F1000W/stage1/jw02107040002_04201_00003_mirimage_fixed
# 2022-07-28 11:47:46,128 - stpipe.Image2Pipeline - INFO - Processing product ./F1000W/stage1/jw02107040002_04201_00004_mirimage_fixed
# 2022-07-28 11:47:46,129 - stpipe.Image2Pipeline - INFO - Working on input ./F1000W/stage1/jw02107040002_04201_00004_mirimage_fixed_rate.fits ...
# 2022-07-28 11:47:46,569 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from jw02107040002_04201_00004_mirimage_fixed_rate.fits>,).
# 2022-07-28 11:47:46,573 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-07-28 11:47:46,987 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2022-07-28 11:47:47,147 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  24.183427866 15.716566614 24.152498473 15.706966581 24.162473207 15.677051051 24.193540988 15.686389338
# 2022-07-28 11:47:47,148 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  24.183427866 15.716566614 24.152498473 15.706966581 24.162473207 15.677051051 24.193540988 15.686389338
# 2022-07-28 11:47:47,149 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-07-28 11:47:47,348 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-07-28 11:47:47,669 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw02107040002_04201_00004_mirimage_fixed_rate.fits>,).
# 2022-07-28 11:47:47,674 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-07-28 11:47:47,903 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-28 11:47:47,905 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-28 11:47:47,906 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-28 11:47:47,919 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-28 11:47:48,172 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2022-07-28 11:47:48,496 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw02107040002_04201_00004_mirimage_fixed_rate.fits>,).
# 2022-07-28 11:47:48,499 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-07-28 11:47:48,562 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits
# 2022-07-28 11:47:48,563 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits
# 2022-07-28 11:47:48,715 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2022-07-28 11:47:48,716 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2022-07-28 11:47:48,717 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2022-07-28 11:47:48,717 - stpipe.Image2Pipeline.photom - INFO -  filter: F1000W
# 2022-07-28 11:47:48,821 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2022-07-28 11:47:48,825 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2022-07-28 11:47:48,827 - stpipe.Image2Pipeline.photom - WARNING - Expected to find one matching row in table, found 0.
# 2022-07-28 11:47:48,828 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 0.369118
# 2022-07-28 11:47:48,868 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2022-07-28 11:47:49,209 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from jw02107040002_04201_00004_mirimage_fixed_rate.fits>,).
# 2022-07-28 11:47:49,214 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': False, 'allowed_memory': None}
# 2022-07-28 11:47:49,277 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-28 11:47:49,315 - stpipe.Image2Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-07-28 11:47:49,315 - stpipe.Image2Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:47:49,316 - stpipe.Image2Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:47:49,317 - stpipe.Image2Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:47:49,557 - stpipe.Image2Pipeline.resample - INFO - Resampling science data
# 2022-07-28 11:47:50,217 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:50,883 - stpipe.Image2Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 11:47:51,576 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:52,269 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 11:47:52,940 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:53,602 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 11:47:54,262 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-28 11:47:54,991 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.183559567 15.716622864 24.152480184 15.707095471 24.162475092 15.676884223 24.193550337 15.686410204
# 2022-07-28 11:47:55,242 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./F1000W/stage2/jw02107040002_04201_00004_mirimage_fixed_i2d.fits
# 2022-07-28 11:47:55,243 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2022-07-28 11:47:55,244 - stpipe.Image2Pipeline - INFO - Finished processing product ./F1000W/stage1/jw02107040002_04201_00004_mirimage_fixed
# 2022-07-28 11:47:55,247 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# 2022-07-28 11:47:55,248 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,249 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,250 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,251 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,251 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,252 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,253 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,254 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,254 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,256 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,257 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,257 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,258 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,259 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,260 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,260 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,261 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,261 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,262 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,263 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:47:55,602 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039001_02103_00001_mirimage_fixed_cal.fits
# 2022-07-28 11:47:55,930 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039001_02103_00002_mirimage_fixed_cal.fits
# 2022-07-28 11:47:56,275 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039001_02103_00003_mirimage_fixed_cal.fits
# 2022-07-28 11:47:56,626 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039001_02103_00004_mirimage_fixed_cal.fits
# 2022-07-28 11:47:56,964 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039002_02103_00001_mirimage_fixed_cal.fits
# 2022-07-28 11:47:57,300 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039002_02103_00002_mirimage_fixed_cal.fits
# 2022-07-28 11:47:57,665 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039002_02103_00003_mirimage_fixed_cal.fits
# 2022-07-28 11:47:58,016 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039002_02103_00004_mirimage_fixed_cal.fits
# 2022-07-28 11:47:58,376 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039003_02103_00001_mirimage_fixed_cal.fits
# 2022-07-28 11:47:58,738 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039003_02103_00002_mirimage_fixed_cal.fits
# 2022-07-28 11:47:59,090 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039003_02103_00003_mirimage_fixed_cal.fits
# 2022-07-28 11:47:59,416 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107039003_02103_00004_mirimage_fixed_cal.fits
# 2022-07-28 11:47:59,747 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040001_04201_00001_mirimage_fixed_cal.fits
# 2022-07-28 11:48:00,100 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040001_04201_00002_mirimage_fixed_cal.fits
# 2022-07-28 11:48:00,431 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040001_04201_00003_mirimage_fixed_cal.fits
# 2022-07-28 11:48:00,807 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040001_04201_00004_mirimage_fixed_cal.fits
# 2022-07-28 11:48:01,160 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040002_04201_00001_mirimage_fixed_cal.fits
# 2022-07-28 11:48:01,524 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040002_04201_00002_mirimage_fixed_cal.fits
# 2022-07-28 11:48:01,883 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040002_04201_00003_mirimage_fixed_cal.fits
# 2022-07-28 11:48:02,211 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02107040002_04201_00004_mirimage_fixed_cal.fits
# 2022-07-28 11:48:02,212 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39001*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# update the WCS for mosaic tile 2
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39002*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile2_shifts)
    
# update the WCS for mosaic tile 3
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39003*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile3_shifts)
    
# update the WCS for mosaic tile 4
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}40001*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile4_shifts)
    
# update the WCS for mosaic tile 5
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}40002*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile5_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F1000W/stage2/jw02107039001_02103_00001_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039001_02103_00002_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039001_02103_00003_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039001_02103_00004_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039002_02103_00001_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039002_02103_00002_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039002_02103_00003_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039002_02103_00004_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039003_02103_00001_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039003_02103_00002_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039003_02103_00003_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107039003_02103_00004_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040001_04201_00001_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040001_04201_00002_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040001_04201_00003_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040001_04201_00004_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040002_04201_00001_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040002_04201_00002_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040002_04201_00003_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02107040002_04201_00004_mirimage_fixed_wcs_cal.fits']
# miri_F1000W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-28 11:48:31,751 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-28 11:48:31,755 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:48:31,756 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-28 11:48:31,761 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-28 11:48:31,762 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-28 11:48:31,766 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-28 11:48:31,767 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-28 11:48:31,772 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-28 11:48:31,774 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-28 11:48:31,778 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 11:48:31,779 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 11:48:31,782 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-28 11:48:31,784 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-28 11:48:32,179 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1000W_stage3_asn.json',).
# 2022-07-28 11:48:32,194 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-28 11:48:32,520 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02103_00001_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-28 11:48:32,544 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-28 11:48:32,545 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-28 11:48:32,546 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:48:32,547 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-28 11:48:39,949 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-28 11:48:39,954 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-28 11:48:39,955 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-28 11:48:40,047 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-28 11:48:40,477 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-28 11:48:40,483 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-28 11:48:40,485 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-28 11:48:40,577 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-28 11:48:40,952 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-28 11:48:40,960 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-28 11:48:40,981 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2022-07-28 11:48:40,982 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2022-07-28 11:48:40,983 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:48:40,984 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:48:40,985 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:48:42,551 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:44,259 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:45,938 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:47,562 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:49,185 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:50,935 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:52,588 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:54,299 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:55,975 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:57,642 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:48:59,292 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:00,953 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:02,623 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:04,269 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:05,963 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:07,644 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:09,265 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:10,897 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:12,515 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:14,122 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:49:24,323 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 20 images
# 2022-07-28 11:49:52,192 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-28 11:49:53,241 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:49:54,357 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:49:55,439 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:49:56,545 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:49:57,721 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:49:58,861 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:00,003 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:01,257 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:02,426 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:03,560 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:04,695 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:05,820 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:06,939 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:08,085 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:09,188 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:10,329 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:11,443 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:12,578 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:13,740 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:14,961 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:50:15,022 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-28 11:50:15,163 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1558 (0.15%)
# 2022-07-28 11:50:15,301 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1692 (0.16%)
# 2022-07-28 11:50:15,435 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 604 (0.06%)
# 2022-07-28 11:50:15,581 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1275 (0.12%)
# 2022-07-28 11:50:15,717 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1629 (0.15%)
# 2022-07-28 11:50:15,854 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1759 (0.17%)
# 2022-07-28 11:50:15,987 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1987 (0.19%)
# 2022-07-28 11:50:16,121 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 2173 (0.21%)
# 2022-07-28 11:50:16,260 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1262 (0.12%)
# 2022-07-28 11:50:16,385 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1325 (0.13%)
# 2022-07-28 11:50:16,517 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1485 (0.14%)
# 2022-07-28 11:50:16,653 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1489 (0.14%)
# 2022-07-28 11:50:16,791 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 246 (0.02%)
# 2022-07-28 11:50:16,920 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 900 (0.09%)
# 2022-07-28 11:50:17,049 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1321 (0.13%)
# 2022-07-28 11:50:17,175 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1407 (0.13%)
# 2022-07-28 11:50:17,304 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 267 (0.03%)
# 2022-07-28 11:50:17,434 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 932 (0.09%)
# 2022-07-28 11:50:17,565 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1292 (0.12%)
# 2022-07-28 11:50:17,708 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1244 (0.12%)
# 2022-07-28 11:50:18,428 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:19,550 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:20,118 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:20,652 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039001_02103_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:21,346 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:21,956 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:22,529 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:23,055 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039002_02103_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:23,672 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:24,310 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:24,935 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:25,588 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107039003_02103_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:26,203 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040001_04201_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:26,719 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040001_04201_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:27,243 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040001_04201_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:27,744 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040001_04201_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:28,258 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040002_04201_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:28,762 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040002_04201_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:29,275 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040002_04201_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:29,780 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02107040002_04201_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-07-28 11:50:29,782 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-07-28 11:50:30,274 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-07-28 11:50:30,278 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}
# 2022-07-28 11:50:30,328 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-28 11:50:30,411 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-07-28 11:50:30,411 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:50:30,412 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:50:30,414 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:50:31,086 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for miri_F1000W_stage3_asn
# 2022-07-28 11:50:33,180 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-07-28 11:50:34,015 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:35,579 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:37,105 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:38,624 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:40,094 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:41,574 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:43,034 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:44,484 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:45,936 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:47,414 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:48,870 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:50,335 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:51,779 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:53,250 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:54,965 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:56,457 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:57,960 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:50:59,537 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:01,072 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:02,572 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:03,320 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-28 11:51:04,245 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:05,878 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:07,450 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:09,025 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:10,632 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:12,167 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:13,706 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:15,221 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:16,752 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:18,278 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:19,863 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:21,421 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:22,943 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:24,495 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:26,041 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:27,579 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:29,305 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:31,001 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:32,585 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:34,259 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:35,019 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-28 11:51:35,919 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:37,558 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:39,164 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:40,817 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:42,422 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:44,209 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:45,783 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:47,326 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:48,918 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:50,572 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:52,157 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:53,764 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:55,272 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:56,800 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:58,352 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:51:59,888 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:01,439 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:02,985 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:04,541 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:06,084 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:06,932 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-07-28 11:52:07,844 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:09,531 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:11,170 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:12,860 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:14,484 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:16,086 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:17,637 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:19,189 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:20,762 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:22,347 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:23,882 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:25,425 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:26,978 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:28,534 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:30,070 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:31,640 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:33,154 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:34,754 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:36,512 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:38,120 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:52:39,020 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.176514777 15.828393710 24.113551745 15.806329114 24.175431937 15.642794708 24.238351054 15.664841566
# 2022-07-28 11:52:40,286 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_i2d.fits
# 2022-07-28 11:52:40,287 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-28 11:52:40,745 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(2110, 5696) from miri_F1000W_stage3_asn_i2d.fits>,).
# 2022-07-28 11:52:40,748 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-28 11:52:40,788 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-28 11:52:40,808 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-28 11:52:40,810 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-28 11:52:40,811 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-28 11:52:40,811 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1000W
# 2022-07-28 11:52:40,812 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-28 11:52:40,927 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.95551
# 2022-07-28 11:52:44,889 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 282 sources
# 2022-07-28 11:52:45,959 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1000W/stage3/miri_F1000W_stage3_asn_cat.ecsv
# 2022-07-28 11:52:46,295 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_segm.fits
# 2022-07-28 11:52:46,298 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1000W_stage3_asn_segm.fits
# 2022-07-28 11:52:46,303 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-28 11:52:46,308 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
