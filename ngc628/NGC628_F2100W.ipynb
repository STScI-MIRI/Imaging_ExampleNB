# %% [markdown]
# ## JWST F2100W NGC628 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 28 Jul 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F2100W"
fwhm = 6.0
basename = "jw021070"

# rotation = 0.0
crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
tile1_shifts = [0.0, 0.0]
tile2_shifts = [0.0, 0.0]
tile3_shifts = [0.0, 0.0]
tile4_shifts = [0.0, 0.0]
tile5_shifts = [0.0, 0.0]
#tweakreg = True
#align_to_gaia = True
#tile1_shifts = [-0.05647150365601337, -0.2759964433337788]
#tile2_shifts = [0.25227164704614663, -0.31523502700888206]
#tile3_shifts = [-0.2545612377015838, -0.3166996893456614]
#tile4_shifts = [-0.257545863147537, -0.31632086761441347]
#tile5_shifts = [-0.2575264791579155, -0.3163360127396757]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [100., 1000.]
# display range for calibrated images
drange_cal = [100., 1000.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = True
run_image2 = True
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.3.dev1+g3e8a10cb.d20220719

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev1+g51f5dfc

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F2100W/stage0/jw02107039001_02107_00001_mirimage_uncal.fits', './F2100W/stage0/jw02107039001_02107_00002_mirimage_uncal.fits', './F2100W/stage0/jw02107039001_02107_00003_mirimage_uncal.fits', './F2100W/stage0/jw02107039001_02107_00004_mirimage_uncal.fits', './F2100W/stage0/jw02107039002_02107_00001_mirimage_uncal.fits', './F2100W/stage0/jw02107039002_02107_00002_mirimage_uncal.fits', './F2100W/stage0/jw02107039002_02107_00003_mirimage_uncal.fits', './F2100W/stage0/jw02107039002_02107_00004_mirimage_uncal.fits', './F2100W/stage0/jw02107039003_02107_00001_mirimage_uncal.fits', './F2100W/stage0/jw02107039003_02107_00002_mirimage_uncal.fits', './F2100W/stage0/jw02107039003_02107_00003_mirimage_uncal.fits', './F2100W/stage0/jw02107039003_02107_00004_mirimage_uncal.fits', './F2100W/stage0/jw02107040001_08201_00001_mirimage_uncal.fits', './F2100W/stage0/jw02107040001_08201_00002_mirimage_uncal.fits', './F2100W/stage0/jw02107040001_08201_00003_mirimage_uncal.fits', './F2100W/stage0/jw02107040001_08201_00004_mirimage_uncal.fits', './F2100W/stage0/jw02107040002_08201_00001_mirimage_uncal.fits', './F2100W/stage0/jw02107040002_08201_00002_mirimage_uncal.fits', './F2100W/stage0/jw02107040002_08201_00003_mirimage_uncal.fits', './F2100W/stage0/jw02107040002_08201_00004_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)
# Out:
# 2022-07-28 11:07:44,607 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-28 11:07:44,609 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,610 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-28 11:07:44,612 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,613 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-28 11:07:44,615 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,616 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-28 11:07:44,619 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,620 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-28 11:07:44,621 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,622 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-07-28 11:07:44,624 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,626 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-07-28 11:07:44,628 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,629 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-07-28 11:07:44,631 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,632 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-07-28 11:07:44,634 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,635 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-07-28 11:07:44,637 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,638 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-07-28 11:07:44,640 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,641 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-07-28 11:07:44,642 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,643 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-07-28 11:07:44,645 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,646 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-07-28 11:07:44,649 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,649 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-07-28 11:07:44,651 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'none', 'override_readnoise': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,652 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-07-28 11:07:44,654 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:07:44,655 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-07-28 11:07:44,753 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('./F2100W/stage0/jw02107039001_02107_00001_mirimage_uncal.fits',).
# ./F2100W/stage0/jw02107039001_02107_00001_mirimage_uncal.fits
# 2022-07-28 11:07:44,783 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_ ...
# 2022-07-28 11:07:47,102 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02107_00001_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2022-07-28 11:07:47,895 - CRDS - INFO -  Fetching  /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0021.fits   46.5 M bytes  (1 / 1 files) (0 / 46.5 M bytes)
# 2022-07-28 11:07:52,643 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits'.
# 2022-07-28 11:07:52,644 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2022-07-28 11:07:52,645 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_ipc_0009.fits'.
# 2022-07-28 11:07:52,646 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0021.fits'.
# 2022-07-28 11:07:52,647 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_mask_0030.fits'.
# 2022-07-28 11:07:52,648 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2022-07-28 11:07:52,649 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits'.
# 2022-07-28 11:07:52,650 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2022-07-28 11:07:52,650 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0070.fits'.
# 2022-07-28 11:07:52,651 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits'.
# 2022-07-28 11:07:52,652 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_saturation_0027.fits'.
# 2022-07-28 11:07:52,653 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2022-07-28 11:07:52,654 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2022-07-28 11:07:52,654 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2022-07-28 11:07:52,655 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2022-07-28 11:07:53,323 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:53,327 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:53,494 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-07-28 11:07:53,495 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2022-07-28 11:07:53,500 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2022-07-28 11:07:53,628 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:53,631 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:53,682 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_mask_0030.fits
# 2022-07-28 11:07:54,095 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2022-07-28 11:07:54,225 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:54,228 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'n_pix_grow_sat': 1}
# 2022-07-28 11:07:54,279 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_saturation_0027.fits
# 2022-07-28 11:07:56,356 - stpipe.Detector1Pipeline.saturation - INFO - Detected 3785 saturated pixels
# 2022-07-28 11:07:56,376 - stpipe.Detector1Pipeline.saturation - INFO - Detected 60 A/D floor pixels
# 2022-07-28 11:07:56,391 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2022-07-28 11:07:56,526 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:56,529 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:56,582 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_ipc_0009.fits
# 2022-07-28 11:07:57,426 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2022-07-28 11:07:57,566 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:57,569 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:57,743 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2022-07-28 11:07:57,877 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:57,880 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:58,043 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2022-07-28 11:07:58,177 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:58,180 - stpipe.Detector1Pipeline.reset - INFO - Step reset parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:58,232 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0070.fits
# 2022-07-28 11:07:58,845 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2022-07-28 11:07:58,976 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:58,979 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:07:59,031 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0021.fits
# 2022-07-28 11:07:59,790 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-07-28 11:07:59,918 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:07:59,921 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'type': 'baseline'}
# 2022-07-28 11:07:59,974 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2022-07-28 11:08:00,210 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2022-07-28 11:08:00,345 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:08:00,348 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'dark_output': None}
# 2022-07-28 11:08:00,400 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits
# 2022-07-28 11:08:06,240 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=14, nframes=1, groupgap=0
# 2022-07-28 11:08:06,241 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-07-28 11:08:10,897 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-07-28 11:08:11,167 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:08:11,169 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-07-28 11:08:11,325 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-07-28 11:08:11,326 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-07-28 11:08:11,327 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-07-28 11:08:11,327 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-07-28 11:08:11,329 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-07-28 11:08:11,330 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-07-28 11:08:11,331 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-07-28 11:08:11,331 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-07-28 11:08:11,333 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-07-28 11:08:11,854 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-07-28 11:08:11,921 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-07-28 11:08:12,073 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:08:12,076 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-07-28 11:08:12,106 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-07-28 11:08:12,107 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-07-28 11:08:12,136 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:08:12,209 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:08:12,514 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-07-28 11:08:12,555 - stpipe.Detector1Pipeline.jump - INFO - Creating 4 processes for jump detection
# 2022-07-28 11:08:12,977 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:08:13,286 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:08:13,445 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:08:13,462 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4039 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:13,464 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 13 pixels with at least one CR from four groups.
# 2022-07-28 11:08:13,465 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 6 pixels with at least one CR from three groups.
# 2022-07-28 11:08:13,632 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:08:13,782 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:08:13,805 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2696 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:13,808 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-07-28 11:08:13,809 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:08:13,948 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:08:14,210 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:08:14,228 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2971 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:14,230 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:08:14,232 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2 pixels with at least one CR from three groups.
# 2022-07-28 11:08:14,627 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:08:14,645 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4721 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:14,647 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 7 pixels with at least one CR from four groups.
# 2022-07-28 11:08:14,649 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 7 pixels with at least one CR from three groups.
# 2022-07-28 11:08:15,391 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:08:15,845 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:08:15,935 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1653 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:15,937 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:08:15,939 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:08:16,385 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1687 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:16,387 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:08:16,388 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:08:16,483 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:08:17,102 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2308 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:17,104 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:08:17,106 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:08:18,231 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:08:18,758 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2307 pixels with at least one CR from five or more groups.
# 2022-07-28 11:08:18,760 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-07-28 11:08:18,762 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:08:20,696 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 8.18087 sec
# 2022-07-28 11:08:20,706 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 8.599913
# 2022-07-28 11:08:20,720 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-07-28 11:08:20,885 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 14, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:08:20,888 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-07-28 11:08:20,963 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:08:20,964 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:08:21,062 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-07-28 11:08:21,063 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-07-28 11:08:21,336 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2022-07-28 11:08:21,338 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2022-07-28 11:08:21,340 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 4
# 2022-07-28 11:08:31,598 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:08:31,602 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:08:32,406 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:08:32,410 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:08:33,755 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:08:33,759 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:08:34,366 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:08:34,370 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:08:34,738 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-07-28 11:08:34,885 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:08:34,888 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:08:34,979 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:08:34,980 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:08:34,990 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:08:35,104 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw02107039001_02107_00001_mirimage_uncal.fits>,).
# 2022-07-28 11:08:35,108 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:08:35,230 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:08:35,231 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:08:35,242 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:08:35,473 - stpipe.Detector1Pipeline - INFO - Saved model in ./F2100W/stage1/jw02107039001_02107_00001_mirimage_rateints.fits
# 2022-07-28 11:08:35,474 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-07-28 11:08:35,475 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:08:35,647 - stpipe.Detector1Pipeline - INFO - Saved model in ./F2100W/stage1/jw02107039001_02107_00001_mirimage_rate.fits
# 2022-07-28 11:08:35,648 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-07-28 11:08:35,666 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-28 11:08:35,668 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,670 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-28 11:08:35,672 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,673 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-28 11:08:35,676 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,678 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-28 11:08:35,680 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,681 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-28 11:08:35,683 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,684 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-07-28 11:08:35,688 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,689 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-07-28 11:08:35,691 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,692 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-07-28 11:08:35,694 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,695 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-07-28 11:08:35,697 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,698 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-07-28 11:08:35,700 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,701 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-07-28 11:08:35,702 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,703 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-07-28 11:08:35,705 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,707 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-07-28 11:08:35,710 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,711 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-07-28 11:08:35,714 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,715 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-07-28 11:08:35,716 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'none', 'override_readnoise': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,717 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-07-28 11:08:35,719 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-28 11:08:35,720 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2022-07-28 11:08:35,862 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('./F2100W/stage0/jw02107039001_02107_00002_mirimage_uncal.fits',).
# ./F2100W/stage0/jw02107039001_02107_00002_mirimage_uncal.fits
# ...
# 2022-07-28 11:20:16,186 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0021.fits
# 2022-07-28 11:20:16,880 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-07-28 11:20:17,047 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 14, 1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:17,050 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'type': 'baseline'}
# 2022-07-28 11:20:17,106 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2022-07-28 11:20:17,332 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2022-07-28 11:20:17,494 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 14, 1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:17,498 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'dark_output': None}
# 2022-07-28 11:20:17,556 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits
# 2022-07-28 11:20:20,137 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=14, nframes=1, groupgap=0
# 2022-07-28 11:20:20,138 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-07-28 11:20:23,060 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-07-28 11:20:23,257 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 14, 1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:23,260 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-07-28 11:20:23,417 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-07-28 11:20:23,418 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-07-28 11:20:23,418 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-07-28 11:20:23,419 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-07-28 11:20:23,420 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-07-28 11:20:23,421 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-07-28 11:20:23,422 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-07-28 11:20:23,422 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-07-28 11:20:23,424 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-07-28 11:20:23,948 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-07-28 11:20:24,018 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-07-28 11:20:24,193 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 14, 1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:24,198 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 0.0, 'after_jump_flag_time1': 0.0, 'after_jump_flag_dn2': 0.0, 'after_jump_flag_time2': 0.0}
# 2022-07-28 11:20:24,228 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-07-28 11:20:24,229 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-07-28 11:20:24,260 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:20:24,337 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:20:24,605 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-07-28 11:20:24,645 - stpipe.Detector1Pipeline.jump - INFO - Creating 4 processes for jump detection
# 2022-07-28 11:20:25,194 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:20:25,538 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:20:25,624 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:20:25,641 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4640 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:25,642 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from four groups.
# 2022-07-28 11:20:25,644 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from three groups.
# 2022-07-28 11:20:25,902 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:20:26,004 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:20:25,983 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:20:26,001 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3154 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:26,003 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:20:26,285 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-28 11:20:26,389 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:20:26,408 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3529 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:26,411 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:20:26,413 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-28 11:20:26,764 - stpipe.Detector1Pipeline.jump - WARNING - /home/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:152: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-28 11:20:26,789 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 5989 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:26,791 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8 pixels with at least one CR from four groups.
# 2022-07-28 11:20:26,794 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-28 11:20:27,637 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:20:28,070 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:20:28,103 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1698 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:28,105 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:20:28,106 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:20:28,426 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:20:28,562 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1477 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:28,564 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:20:28,566 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:20:28,911 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2682 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:28,913 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:20:28,915 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:20:30,283 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-28 11:20:30,736 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2685 pixels with at least one CR from five or more groups.
# 2022-07-28 11:20:30,737 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-28 11:20:30,739 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-28 11:20:32,593 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 7.98683 sec
# 2022-07-28 11:20:32,606 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 8.378365
# 2022-07-28 11:20:32,621 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-07-28 11:20:32,828 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 14, 1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:32,832 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F2100W/stage0', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-07-28 11:20:32,913 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-28 11:20:32,914 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-28 11:20:33,019 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-07-28 11:20:33,020 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-07-28 11:20:33,263 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2022-07-28 11:20:33,265 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2022-07-28 11:20:33,267 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 4
# 2022-07-28 11:20:42,958 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:20:42,961 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:20:43,436 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:20:43,439 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:20:44,150 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:20:44,153 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:20:45,543 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 12
# 2022-07-28 11:20:45,547 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-28 11:20:45,887 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-07-28 11:20:46,094 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:46,098 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:20:46,191 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:20:46,192 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:20:46,201 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:20:46,378 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw02107040002_08201_00004_mirimage_uncal.fits>,).
# 2022-07-28 11:20:46,382 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F2100W/stage0'}
# 2022-07-28 11:20:46,483 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-28 11:20:46,484 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-28 11:20:46,500 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-28 11:20:46,706 - stpipe.Detector1Pipeline - INFO - Saved model in ./F2100W/stage1/jw02107040002_08201_00004_mirimage_rateints.fits
# 2022-07-28 11:20:46,707 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-07-28 11:20:46,708 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0939.pmap
# 2022-07-28 11:20:46,872 - stpipe.Detector1Pipeline - INFO - Saved model in ./F2100W/stage1/jw02107040002_08201_00004_mirimage_rate.fits
# 2022-07-28 11:20:46,873 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F2100W/stage1/jw02107039001_02107_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039001_02107_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039001_02107_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039001_02107_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00004_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)
# Out:
# 2022-07-28 11:21:05,936 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2022-07-28 11:21:05,939 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None, 'override_wfssbkg': None, 'override_wavelengthrange': None, 'class': ''}
#
#
# 2022-07-28 11:21:05,941 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-07-28 11:21:05,944 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55, 'override_distortion': None, 'override_filteroffset': None, 'override_specwcs': None, 'override_regions': None, 'override_wavelengthrange': None, 'override_camera': None, 'override_collimator': None, 'override_disperser': None, 'override_fore': None, 'override_fpa': None, 'override_msa': None, 'override_ote': None, 'override_ifupost': None, 'override_ifufore': None, 'override_ifuslicer': None, 'class': ''}
#
#
# 2022-07-28 11:21:05,946 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-07-28 11:21:05,949 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False, 'override_flat': None, 'override_fflat': None, 'override_sflat': None, 'override_dflat': None, 'class': ''}
#
#
# 2022-07-28 11:21:05,950 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-07-28 11:21:05,953 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'inverse': False, 'source_type': None, 'override_photom': None, 'override_area': None, 'class': ''}
#
#
# 2022-07-28 11:21:05,955 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-07-28 11:21:05,957 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 11:21:05,958 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 11:21:06,203 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args (['./F2100W/stage1/jw02107039001_02107_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039001_02107_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039001_02107_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039001_02107_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039002_02107_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107039003_02107_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040001_08201_00004_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00001_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00002_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00003_mirimage_fixed_rate.fits', './F2100W/stage1/jw02107040002_08201_00004_mirimage_fixed_rate.fits'],).
# 2022-07-28 11:21:06,215 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage2', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# 2022-07-28 11:21:07,966 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02107_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-07-28 11
- stpipe.Image2Pipeline - INFO - Saved model in ./F2100W/stage2/jw02107040002_08201_00003_mirimage_fixed_cal.fits
# 2022-07-28 11:24:12,943 - stpipe.Image2Pipeline - INFO - Saved model in ./F2100W/stage2/jw02107040002_08201_00004_mirimage_fixed_cal.fits
# 2022-07-28 11:24:12,944 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39001*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# update the WCS for mosaic tile 2
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39002*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile2_shifts)
    
# update the WCS for mosaic tile 3
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}39003*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile3_shifts)
    
# update the WCS for mosaic tile 4
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}40001*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile4_shifts)
    
# update the WCS for mosaic tile 5
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}40002*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile5_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F2100W/stage2/jw02107039001_02107_00001_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039001_02107_00002_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039001_02107_00003_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039001_02107_00004_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039002_02107_00001_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039002_02107_00002_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039002_02107_00003_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039002_02107_00004_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039003_02107_00001_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039003_02107_00002_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039003_02107_00003_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107039003_02107_00004_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040001_08201_00001_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040001_08201_00002_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040001_08201_00003_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040001_08201_00004_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040002_08201_00001_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040002_08201_00002_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040002_08201_00003_mirimage_fixed_wcs_cal.fits', './F2100W/stage2/jw02107040002_08201_00004_mirimage_fixed_wcs_cal.fits']
# miri_F2100W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-28 11:24:42,576 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-28 11:24:42,579 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-28 11:24:42,580 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-28 11:24:42,585 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-28 11:24:42,588 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-28 11:24:42,592 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-28 11:24:42,594 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-28 11:24:42,600 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-28 11:24:42,603 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-28 11:24:42,607 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-28 11:24:42,609 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-28 11:24:42,613 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-28 11:24:42,614 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-28 11:24:43,045 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F2100W_stage3_asn.json',).
# 2022-07-28 11:24:43,061 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F2100W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 6.0, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-28 11:24:43,418 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02107039001_02107_00001_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-28 11:24:43,450 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-28 11:24:43,451 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-28 11:24:43,452 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-28 11:24:43,454 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-28 11:24:51,821 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-28 11:24:51,827 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 6.0, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-28 11:24:51,828 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-28 11:24:51,927 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-28 11:24:52,372 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-28 11:24:52,377 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-28 11:24:52,379 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-28 11:24:52,481 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-28 11:24:52,898 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-28 11:24:52,904 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-28 11:24:52,927 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 20 inputs
# 2022-07-28 11:24:52,928 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2022-07-28 11:24:52,929 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2022-07-28 11:24:52,930 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2022-07-28 11:24:52,931 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2022-07-28 11:24:55,051 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:24:57,107 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:24:59,251 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:01,563 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:03,523 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:05,607 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:07,495 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:09,650 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:11,827 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:13,855 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:15,997 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:18,244 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:20,315 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:22,467 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:24,471 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:26,509 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:28,675 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:30,947 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:33,162 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:35,269 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (2092, 5648)
# 2022-07-28 11:25:50,373 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 20 images
# 2022-07-28 11:26:28,074 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-28 11:26:29,094 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:30,164 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:31,229 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:32,349 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:33,499 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:34,641 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:35,793 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:36,937 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:38,070 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:39,213 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:40,351 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:41,483 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:42,603 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:43,721 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:44,851 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:45,973 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:47,105 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:48,408 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:49,775 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:50,906 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (2092, 5648)
# 2022-07-28 11:26:50,972 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-28 11:26:51,121 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4228 (0.40%)
# 2022-07-28 11:26:51,266 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4574 (0.43%)
# 2022-07-28 11:26:51,411 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 3488 (0.33%)
# 2022-07-28 11:26:51,561 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 3203 (0.30%)
# 2022-07-28 11:26:51,710 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4334 (0.41%)
# 2022-07-28 11:26:51,858 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4430 (0.42%)
# 2022-07-28 11:26:52,005 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4681 (0.44%)
# 2022-07-28 11:26:52,153 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4260 (0.40%)
# 2022-07-28 11:26:52,299 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1958 (0.19%)
# 2022-07-28 11:26:52,447 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1915 (0.18%)
# 2022-07-28 11:26:52,595 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 2883 (0.27%)
# 2022-07-28 11:26:52,739 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 2492 (0.24%)
# 2022-07-28 11:26:52,884 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1834 (0.17%)
# 2022-07-28 11:26:53,028 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1946 (0.18%)
# 2022-07-28 11:26:53,174 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1685 (0.16%)
# 2022-07-28 11:26:53,319 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 
- stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:28:58,842 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:00,384 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:01,928 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:03,495 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:05,055 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:06,603 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:08,147 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:09,695 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (2110, 5696)
# 2022-07-28 11:29:10,558 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  24.176505702 15.828386924 24.113542684 15.806322298 24.175422956 15.642787921 24.238342060 15.664834808
# 2022-07-28 11:29:11,829 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F2100W/stage3/miri_F2100W_stage3_asn_i2d.fits
# 2022-07-28 11:29:11,830 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-28 11:29:12,301 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(2110, 5696) from miri_F2100W_stage3_asn_i2d.fits>,).
# 2022-07-28 11:29:12,305 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-28 11:29:12,347 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-28 11:29:12,368 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-28 11:29:12,369 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-28 11:29:12,371 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-28 11:29:12,372 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F2100W
# 2022-07-28 11:29:12,373 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-28 11:29:12,489 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 6.53267
# 2022-07-28 11:29:16,385 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 250 sources
# 2022-07-28 11:29:17,428 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F2100W/stage3/miri_F2100W_stage3_asn_cat.ecsv
# 2022-07-28 11:29:17,785 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F2100W/stage3/miri_F2100W_stage3_asn_segm.fits
# 2022-07-28 11:29:17,788 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F2100W_stage3_asn_segm.fits
# 2022-07-28 11:29:17,791 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-28 11:29:17,796 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
