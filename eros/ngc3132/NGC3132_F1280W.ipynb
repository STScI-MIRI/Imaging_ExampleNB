# %% [markdown]
# ## JWST F1280W NGC3132 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 18 Jul 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1280W"
fwhm = 3.7
basename = "jw0273300200"

crval = [151.75705520150103, -40.436433360520084]
# rotation = 112.
# crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
tile1_shifts = [0.17320409635878223, -0.06012765659475183]
tile2_shifts = [0.17320409635878223, -0.06012765659475183]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [30., 200.]
# display range for calibrated images
drange_cal = [10., 200.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = True
run_image2 = True
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev2+g6262cda

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F1280W/stage0/jw02733002001_02105_00004_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00008_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00007_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00006_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00006_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00004_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00007_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00003_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00001_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00001_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00005_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00005_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00003_mirimage_uncal.fits', './F1280W/stage0/jw02733002001_02105_00002_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00002_mirimage_uncal.fits', './F1280W/stage0/jw02733002002_02105_00008_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)
# Out:
# 2022-07-18 15:39:17,593 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-18 15:39:17,594 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,594 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-18 15:39:17,595 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,595 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-18 15:39:17,596 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,596 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-18 15:39:17,597 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,597 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-18 15:39:17,598 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,598 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-07-18 15:39:17,599 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,600 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-07-18 15:39:17,601 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,601 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-07-18 15:39:17,602 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,602 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-07-18 15:39:17,603 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,603 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-07-18 15:39:17,604 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,604 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-07-18 15:39:17,605 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,605 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-07-18 15:39:17,606 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,606 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-07-18 15:39:17,607 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,608 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-07-18 15:39:17,609 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,609 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-07-18 15:39:17,610 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'none', 'override_readnoise': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,610 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-07-18 15:39:17,611 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_gain': None, 'class': ''}
#
#
# 2022-07-18 15:39:17,612 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# ./F1280W/stage0/jw02733002001_02105_00004_mirimage_uncal.fits
# 2022-07-18 15:39:17,698 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args 
- stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02105_00004_mirimage_uncal.fits>,).
# 2022-07-18 15:39:27,540 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1280W/stage0', 'type': 'baseline'}
# 2022-07-18 15:39:27,559 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2022-07-18 15:39:27,792 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2022-07-18 15:39:27,885 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02105_00004_mirimage_uncal.fits>,).
# 2022-07-18 15:39:27,886 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1280W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1280W/stage0', 'dark_output': None}
# 2022-07-18 15:39:27,904 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits
# 2022-07-18 15:39:30,151 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=30, nframes=1, groupgap=0
# 2022-07-18 15:39:30,151 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-07-18 15:39:31,629 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-07-18 15:39:31,959 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02105_00004_mirimage_uncal.fits>,).
# 2022-07-18 15:39:31,960 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1280W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-07-18 15:39:32,154 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-07-18 15:39:32,154 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-07-18 15:39:32,154 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-07-18 15:39:32,155 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-07-18 15:39:32,155 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-07-18 15:39:32,155 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-07-18 15:39:32,155 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-07-18 15:39:32,155 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-07-18 15:39:32,157 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-07-18 15:39:32,752 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-07-18 15:39:32,823 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-07-18 15:39:32,962 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02105_00004_mirimage_uncal.fits>,).
# 2022-07-18 15:39:32,964 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1280W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-07-18 15:39:32,972 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-07-18 15:39:32,973 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-07-18 15:39:32,985 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-18 15:39:33,020 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-18 15:39:33,345 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-07-18 15:39:33,485 - stpipe.Detector1Pipeline.jump - INFO - Creating 10 processes for jump detection
# 2022-07-18 15:39:33,740 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:33,849 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:33,962 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:33,970 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:39:33,975 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4769 pixels with at least one CR from five groups.
# 2022-07-18 15:39:33,976 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from four groups.
# 2022-07-18 15:39:33,977 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,072 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:34,076 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:39:34,081 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2219 pixels with at least one CR from five groups.
# 2022-07-18 15:39:34,082 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:39:34,083 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,193 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2744 pixels with at least one CR from five groups.
# 2022-07-18 15:39:34,194 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:39:34,193 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:34,195 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,296 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:34,300 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:39:34,305 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2773 pixels with at least one CR from five groups.
# 2022-07-18 15:39:34,306 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:39:34,307 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,406 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:34,529 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2705 pixels with at least one CR from five groups.
# 2022-07-18 15:39:34,530 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:39:34,531 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,539 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:39:34,546 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3133 pixels with at least one CR from five groups.
# 2022-07-18 15:39:34,547 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:39:34,548 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,566 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:34,649 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:39:34,663 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:39:34,668 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2350 pixels with at least one CR from five groups.
# 2022-07-18 15:39:34,669 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3 pixels with at least one CR from four groups.
# 2022-07-18 15:39:34,670 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,724 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:39:34,835 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:39:34,828 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15
- stpipe.Detector1Pipeline - INFO - Saved model in ./F1280W/stage1/jw02733002001_02105_00004_mirimage_rate.fits
# 2022-07-18 15:39:50,489 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-07-18 15:39:50,496 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-18 15:39:50,497 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:39:50,497 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-18 15:39:50,498 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-18 15:39:50,499 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-18 15:39:50,499 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-18 15:39:50,500 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-18 15:39:50,500 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-18 15:39:50,501 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-18 15:39:50,501 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-18 15:39:50,502 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# ...
# 2022-07-18 15:47:32,393 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:47:32,483 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:47:32,525 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:47:32,532 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2296 pixels with at least one CR from five groups.
# 2022-07-18 15:47:32,533 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:32,534 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:32,552 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:47:32,621 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:47:32,626 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2838 pixels with at least one CR from five groups.
# 2022-07-18 15:47:32,627 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:32,628 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-18 15:47:32,628 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:47:32,672 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2734 pixels with at least one CR from five groups.
# 2022-07-18 15:47:32,674 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:32,675 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:32,759 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:47:32,765 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2784 pixels with at least one CR from five groups.
# 2022-07-18 15:47:32,766 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:32,766 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-18 15:47:32,779 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:47:32,784 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2564 pixels with at least one CR from five groups.
# 2022-07-18 15:47:32,785 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-07-18 15:47:32,786 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:32,809 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:32,883 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:32,903 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:47:32,911 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4027 pixels with at least one CR from five groups.
# 2022-07-18 15:47:32,912 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 14 pixels with at least one CR from four groups.
# 2022-07-18 15:47:32,913 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2 pixels with at least one CR from three groups.
# 2022-07-18 15:47:32,943 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:33,013 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2339 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,014 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,015 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,091 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2599 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,092 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,093 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,149 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2302 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,150 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,151 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,334 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:33,358 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:33,414 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:33,467 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:33,467 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:33,547 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2369 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,548 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,549 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,574 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2557 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,575 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,576 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,638 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2248 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,639 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,640 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,687 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2263 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,689 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,688 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2353 pixels with at least one CR from five groups.
# 2022-07-18 15:47:33,689 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,689 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:33,690 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:33,916 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:34,112 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4382 pixels with at least one CR from five groups.
# 2022-07-18 15:47:34,113 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:34,114 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:34,620 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:47:34,819 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3584 pixels with at least one CR from five groups.
# 2022-07-18 15:47:34,820 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:47:34,820 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:47:36,442 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 5.11656 sec
# 2022-07-18 15:47:36,460 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 5.506288
# 2022-07-18 15:47:36,465 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-07-18 15:47:36,621 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 30, 1024, 1032) from jw02733002002_02105_00008_mirimage_uncal.fits>,).
# 2022-07-18 15:47:36,622 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1280W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1280W/stage0', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-07-18 15:47:36,655 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-18 15:47:36,655 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-18 15:47:36,700 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-07-18 15:47:36,700 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-07-18 15:47:36,967 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2022-07-18 15:47:36,968 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2022-07-18 15:47:36,969 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 10
# 2022-07-18 15:47:43,861 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:43,863 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:44,162 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:44,164 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:44,190 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:44,192 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:44,390 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:44,392 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:44,409 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:44,412 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:44,471 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:44,473 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:44,696 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:44,698 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:45,409 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:45,411 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:45,586 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:45,588 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:46,769 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:47:46,772 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:47:46,923 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-07-18 15:47:47,061 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02733002002_02105_00008_mirimage_uncal.fits>,).
# 2022-07-18 15:47:47,066 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F1280W/stage0'}
# 2022-07-18 15:47:47,106 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-18 15:47:47,107 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-18 15:47:47,111 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-18 15:47:47,221 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw02733002002_02105_00008_mirimage_uncal.fits>,).
# 2022-07-18 15:47:47,222 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F1280W/stage0'}
# 2022-07-18 15:47:47,260 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-18 15:47:47,260 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-18 15:47:47,264 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-18 15:47:47,947 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1280W/stage1/jw02733002002_02105_00008_mirimage_rateints.fits
# 2022-07-18 15:47:47,948 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-07-18 15:47:47,948 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:47:48,362 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1280W/stage1/jw02733002002_02105_00008_mirimage_rate.fits
# 2022-07-18 15:47:48,363 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F1280W/stage1/jw02733002001_02105_00006_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00002_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00003_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00006_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00007_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00005_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00002_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00004_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00007_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00004_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00001_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00005_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00008_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002001_02105_00003_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00008_mirimage_fixed_rate.fits', './F1280W/stage1/jw02733002002_02105_00001_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)
# Out:
# 2022-07-18 15:48:13,836 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2022-07-18 15:48:13,837 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract':
- stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:49:47,128 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00006_mirimage_fixed_cal.fits
# 2022-07-18 15:49:47,752 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00002_mirimage_fixed_cal.fits
# 2022-07-18 15:49:48,387 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00003_mirimage_fixed_cal.fits
# 2022-07-18 15:49:49,007 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00006_mirimage_fixed_cal.fits
# 2022-07-18 15:49:49,647 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00007_mirimage_fixed_cal.fits
# 2022-07-18 15:49:50,269 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00005_mirimage_fixed_cal.fits
# 2022-07-18 15:49:50,849 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00002_mirimage_fixed_cal.fits
# 2022-07-18 15:49:51,509 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00004_mirimage_fixed_cal.fits
# 2022-07-18 15:49:52,137 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00007_mirimage_fixed_cal.fits
# 2022-07-18 15:49:52,751 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00004_mirimage_fixed_cal.fits
# 2022-07-18 15:49:53,344 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00001_mirimage_fixed_cal.fits
# 2022-07-18 15:49:53,989 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00005_mirimage_fixed_cal.fits
# 2022-07-18 15:49:54,614 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00008_mirimage_fixed_cal.fits
# 2022-07-18 15:49:55,257 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002001_02105_00003_mirimage_fixed_cal.fits
# 2022-07-18 15:49:55,882 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00008_mirimage_fixed_cal.fits
# 2022-07-18 15:49:56,504 - stpipe.Image2Pipeline - INFO - Saved model in ./F1280W/stage2/jw02733002002_02105_00001_mirimage_fixed_cal.fits
# 2022-07-18 15:49:56,505 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}1*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# update the WCS for mosaic tile 2
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}2*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile2_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F1280W/stage2/jw02733002002_02105_00006_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00007_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00004_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00003_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00006_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00002_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00005_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00003_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00001_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00008_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00001_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00008_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00005_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00004_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002002_02105_00007_mirimage_fixed_wcs_cal.fits', './F1280W/stage2/jw02733002001_02105_00002_mirimage_fixed_wcs_cal.fits']
# miri_F1280W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-18 15:50:24,228 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-18 15:50:24,229 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:50:24,230 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-18 15:50:24,231 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-18 15:50:24,231 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-18 15:50:24,232 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-18 15:50:24,233 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-18 15:50:24,234 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-18 15:50:24,234 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-18 15:50:24,236 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-18 15:50:24,236 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-18 15:50:24,237 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-18 15:50:24,238 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-18 15:50:24,495 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1280W_stage3_asn.json',).
# 2022-07-18 15:50:24,501 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1280W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 3.7, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [151.75705520150103, -40.436433360520084], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-18 15:50:24,711 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02733002002_02105_00006_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-18 15:50:24,724 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-18 15:50:24,726 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-18 15:50:24,727 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-18 15:50:24,728 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-18 15:50:28,487 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-18 15:50:28,490 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 3.7, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-18 15:50:28,491 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-18 15:50:28,552 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-18 15:50:28,918 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-18 15:50:28,920 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-18 15:50:28,920 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-18 15:50:28,970 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-18 15:50:29,253 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-18 15:50:29,255 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-18 15:50:29,263 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 16 inputs
# 2022-07-18 15:50:30,302 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:31,401 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:32,484 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:33,637 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:34,801 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:36,433 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:37,765 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:39,254 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:40,788 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:42,368 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:43,613 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:44,752 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:45,946 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:47,014 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:48,161 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:49,312 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:50:51,039 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 16 images
# 2022-07-18 15:50:52,488 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-18 15:50:53,246 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:54,118 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:55,019 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:55,881 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:56,741 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:57,590 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:58,477 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:50:59,348 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:00,223 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:01,137 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:02,017 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:02,907 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:03,782 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:04,666 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:05,571 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:06,437 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:51:06,477 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-18 15:51:06,559 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 3590 (0.34%)
# 2022-07-18 15:51:06,637 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 5332 (0.50%)
# 2022-07-18 15:51:06,715 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1479 (0.14%)
# 2022-07-18 15:51:06,795 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4725 (0.45%)
# 2022-07-18 15:51:06,873 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers:
- stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:28,032 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:29,003 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:29,981 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:31,135 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:32,504 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:33,614 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:35,041 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1173, 1749)
# 2022-07-18 15:52:35,559 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  151.713777592 -40.452461386 151.752437526 -40.472942249 151.792542611 -40.429071552 151.753895677 -40.408604046
# 2022-07-18 15:52:37,110 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1280W/stage3/miri_F1280W_stage3_asn_i2d.fits
# 2022-07-18 15:52:37,111 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-18 15:52:37,512 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1173, 1749) from miri_F1280W_stage3_asn_i2d.fits>,).
# 2022-07-18 15:52:37,514 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-18 15:52:37,539 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-18 15:52:37,550 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-18 15:52:37,551 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-18 15:52:37,551 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-18 15:52:37,551 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1280W
# 2022-07-18 15:52:37,552 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-18 15:52:37,643 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 5.24056
# 2022-07-18 15:52:37,755 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1173, 1749).
# 2022-07-18 15:52:38,087 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 50 sources
# 2022-07-18 15:52:38,417 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1280W/stage3/miri_F1280W_stage3_asn_cat.ecsv
# 2022-07-18 15:52:38,695 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1280W/stage3/miri_F1280W_stage3_asn_segm.fits
# 2022-07-18 15:52:38,697 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1280W_stage3_asn_segm.fits
# 2022-07-18 15:52:38,698 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-18 15:52:38,701 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
