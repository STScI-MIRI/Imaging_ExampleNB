# %% [markdown]
# ## JWST F1130W NGC3132 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 18 Jul 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1130W"
fwhm = 3.3
basename = "jw0273300200"

crval = [151.75705520150103, -40.436433360520084]
# rotation = 112.
# crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
tile1_shifts = [0.17320409635878223, -0.06012765659475183]
tile2_shifts = [0.17320409635878223, -0.06012765659475183]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [15., 350.]
# display range for calibrated images
drange_cal = [4., 200.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = True
run_image2 = True
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev2+g6262cda

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F1130W/stage0/jw02733002001_02103_00006_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00002_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00005_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00003_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00006_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00008_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00007_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00003_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00005_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00008_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00002_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00001_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00007_mirimage_uncal.fits', './F1130W/stage0/jw02733002002_02103_00004_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00004_mirimage_uncal.fits', './F1130W/stage0/jw02733002001_02103_00001_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)
# Out:
# 2022-07-18 15:20:51,302 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-18 15:20:51,303 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,304 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-18 15:20:51,305 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,306 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-18 15:20:51,307 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,307 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-18 15:20:51,309 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,309 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-18 15:20:51,310 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,311 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-07-18 15:20:51,312 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,312 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-07-18 15:20:51,314 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,314 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-07-18 15:20:51,315 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,316 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-07-18 15:20:51,317 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,317 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-07-18 15:20:51,319 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,319 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-07-18 15:20:51,320 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,321 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-07-18 15:20:51,322 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,322 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-07-18 15:20:51,324 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,324 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-07-18 15:20:51,326 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-07-18 15:20:51,326 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-07-18 15:20:51,327 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 
ameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1130W/stage0'}
# 2022-07-18 15:21:00,514 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0070.fits
# 2022-07-18 15:21:00,909 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2022-07-18 15:21:01,004 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:01,005 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1130W/stage0'}
# 2022-07-18 15:21:01,023 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0032.fits
# 2022-07-18 15:21:01,799 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2022-07-18 15:21:01,893 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:01,894 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1130W/stage0', 'type': 'baseline'}
# 2022-07-18 15:21:01,912 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2022-07-18 15:21:02,182 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2022-07-18 15:21:02,277 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:02,278 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1130W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1130W/stage0', 'dark_output': None}
# 2022-07-18 15:21:02,297 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0082.fits
# 2022-07-18 15:21:04,487 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=30, nframes=1, groupgap=0
# 2022-07-18 15:21:04,488 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-07-18 15:21:06,015 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-07-18 15:21:06,315 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:06,316 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1130W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-07-18 15:21:06,512 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-07-18 15:21:06,512 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-07-18 15:21:06,512 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-07-18 15:21:06,513 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-07-18 15:21:06,513 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-07-18 15:21:06,513 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-07-18 15:21:06,513 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-07-18 15:21:06,514 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-07-18 15:21:06,515 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-07-18 15:21:07,129 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-07-18 15:21:07,200 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-07-18 15:21:07,339 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 30, 1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:07,341 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1130W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-07-18 15:21:07,350 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-07-18 15:21:07,350 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-07-18 15:21:07,361 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-07-18 15:21:07,395 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-07-18 15:21:07,724 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-07-18 15:21:07,800 - stpipe.Detector1Pipeline.jump - INFO - Creating 10 processes for jump detection
# 2022-07-18 15:21:08,021 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:21:08,130 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:21:08,242 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:21:08,246 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:21:08,251 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4523 pixels with at least one CR from five groups.
# 2022-07-18 15:21:08,252 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 11 pixels with at least one CR from four groups.
# 2022-07-18 15:21:08,252 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 5 pixels with at least one CR from three groups.
# 2022-07-18 15:21:08,357 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:21:08,357 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:21:08,362 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2776 pixels with at least one CR from five groups.
# 2022-07-18 15:21:08,363 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:21:08,364 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:21:08,467 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:21:08,469 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:21:08,472 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2902 pixels with at least one CR from five groups.
# 2022-07-18 15:21:08,473 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:21:08,474 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:21:08,588 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:21:08,591 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:21:08,593 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2616 pixels with at least one CR from five groups.
# 2022-07-18 15:21:08,594 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 
- stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:21,345 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:21,347 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:21,430 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:21,432 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:21,528 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:21,530 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:21,603 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:21,605 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:22,166 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:22,167 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:22,676 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:22,678 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:22,776 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:22,777 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:23,214 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:23,216 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:23,392 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 28
# 2022-07-18 15:21:23,394 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-07-18 15:21:23,553 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-07-18 15:21:23,662 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:23,663 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F1130W/stage0'}
# 2022-07-18 15:21:23,718 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-18 15:21:23,718 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-18 15:21:23,722 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-18 15:21:23,819 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw02733002001_02103_00006_mirimage_uncal.fits>,).
# 2022-07-18 15:21:23,820 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F1130W/stage0'}
# 2022-07-18 15:21:23,862 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-07-18 15:21:23,862 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-07-18 15:21:23,866 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-07-18 15:21:25,282 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1130W/stage1/jw02733002001_02103_00006_mirimage_rateints.fits
# 2022-07-18 15:21:25,283 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-07-18 15:21:25,284 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:21:25,793 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1130W/stage1/jw02733002001_02103_00006_mirimage_rate.fits
# 2022-07-18 15:21:25,794 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2022-07-18 15:21:25,800 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-07-18 15:21:25,801 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:21:25,802 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-07-18 15:21:25,802 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-07-18 15:21:25,803 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-07-18 15:21:25,804 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-07-18 15:21:25,804 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-07-18 15:21:25,805 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-07-18 15:21:25,806 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-07-18 15:21:25,806 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-07-18 15:21:25,807 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# ...
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:29:33,963 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2658 pixels with at least one CR from five groups.
# 2022-07-18 15:29:33,964 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-07-18 15:29:33,965 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:29:33,979 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:29:34,071 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:29:34,076 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3053 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,077 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:29:34,078 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3 pixels with at least one CR from three groups.
# 2022-07-18 15:29:34,098 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:29:34,188 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:29:34,193 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2757 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,194 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from four groups.
# 2022-07-18 15:29:34,195 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3 pixels with at least one CR from three groups.
# 2022-07-18 15:29:34,282 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:29:34,308 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:29:34,313 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3013 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,314 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:29:34,315 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:29:34,391 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-07-18 15:29:34,427 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:29:34,455 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:29:34,503 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:29:34,523 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:29:34,528 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2436 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,529 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4 pixels with at least one CR from four groups.
# 2022-07-18 15:29:34,530 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-07-18 15:29:34,632 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2181 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,634 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:29:34,635 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:29:34,676 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 2497 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,677 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-07-18 15:29:34,679 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-07-18 15:29:34,697 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-07-18 15:29:34,697 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-07-18 15:29:34,703 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 4233 pixels with at least one CR from five groups.
# 2022-07-18 15:29:34,704 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found
- stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F1130W/stage1/jw02733002002_02103_00006_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00003_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00008_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00001_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00003_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00002_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00002_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00004_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00008_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00001_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00005_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00007_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00005_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00007_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00006_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00004_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)
# Out:
# 2022-07-18 15:30:18,868 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2022-07-18 15:30:18,870 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None, 'override_wfssbkg': None, 'override_wavelengthrange': None, 'class': ''}
#
#
# 2022-07-18 15:30:18,870 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-07-18 15:30:18,871 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55, 'override_distortion': None, 'override_filteroffset': None, 'override_specwcs': None, 'override_regions': None, 'override_wavelengthrange': None, 'override_camera': None, 'override_collimator': None, 'override_disperser': None, 'override_fore': None, 'override_fpa': None, 'override_msa': None, 'override_ote': None, 'override_ifupost': None, 'override_ifufore': None, 'override_ifuslicer': None, 'class': ''}
#
#
# 2022-07-18 15:30:18,871 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-07-18 15:30:18,872 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False, 'override_flat': None, 'override_fflat': None, 'override_sflat': None, 'override_dflat': None, 'class': ''}
#
#
# 2022-07-18 15:30:18,873 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-07-18 15:30:18,873 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'inverse': False, 'source_type': None, 'override_photom': None, 'override_area': None, 'class': ''}
#
#
# 2022-07-18 15:30:18,874 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-07-18 15:30:18,875 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-18 15:30:18,875 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-18 15:30:19,044 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args (['./F1130W/stage1/jw02733002002_02103_00006_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002001_02103_00003_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00008_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00001_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733002002_02103_00003_mirimage_fixed_rate.fits', './F1130W/stage1/jw02733
'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-07-18 15:31:46,315 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-18 15:31:46,316 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-18 15:31:46,316 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-18 15:31:46,321 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-07-18 15:31:46,446 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2022-07-18 15:31:46,652 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw02733002002_02103_00004_mirimage_fixed_rate.fits>,).
# 2022-07-18 15:31:46,653 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-07-18 15:31:46,677 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits
# 2022-07-18 15:31:46,677 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits
# 2022-07-18 15:31:46,766 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2022-07-18 15:31:46,766 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2022-07-18 15:31:46,766 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2022-07-18 15:31:46,767 - stpipe.Image2Pipeline.photom - INFO -  filter: F1130W
# 2022-07-18 15:31:46,807 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2022-07-18 15:31:46,809 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2022-07-18 15:31:46,810 - stpipe.Image2Pipeline.photom - WARNING - Expected to find one matching row in table, found 0.
# 2022-07-18 15:31:46,810 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 1.18843
# 2022-07-18 15:31:46,826 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2022-07-18 15:31:47,032 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from jw02733002002_02103_00004_mirimage_fixed_rate.fits>,).
# 2022-07-18 15:31:47,034 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': False, 'allowed_memory': None}
# 2022-07-18 15:31:47,058 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-07-18 15:31:47,246 - stpipe.Image2Pipeline.resample - INFO - Resampling science data
# 2022-07-18 15:31:47,761 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-18 15:31:48,089 - stpipe.Image2Pipeline.resample - INFO - Resampling var_rnoise
# 2022-07-18 15:31:48,612 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-18 15:31:48,946 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2022-07-18 15:31:49,477 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-18 15:31:49,818 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2022-07-18 15:31:50,342 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-07-18 15:31:50,688 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  151.714401286 -40.452800253 151.748264152 -40.470737645 151.772058717 -40.444714701 151.738202610 -40.426784253
# 2022-07-18 15:31:51,290 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00004_mirimage_fixed_i2d.fits
# 2022-07-18 15:31:51,291 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2022-07-18 15:31:51,291 - stpipe.Image2Pipeline - INFO - Finished processing product ./F1130W/stage1/jw02733002002_02103_00004_mirimage_fixed
# 2022-07-18 15:31:51,292 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# 2022-07-18 15:31:51,293 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,293 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,293 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,294 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,294 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,294 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,294 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,294 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,295 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,295 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,296 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,296 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,296 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,296 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,296 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:51,297 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0928.pmap
# 2022-07-18 15:31:52,025 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00006_mirimage_fixed_cal.fits
# 2022-07-18 15:31:52,669 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00003_mirimage_fixed_cal.fits
# 2022-07-18 15:31:53,341 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00008_mirimage_fixed_cal.fits
# 2022-07-18 15:31:53,976 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00001_mirimage_fixed_cal.fits
# 2022-07-18 15:31:54,628 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00003_mirimage_fixed_cal.fits
# 2022-07-18 15:31:55,269 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00002_mirimage_fixed_cal.fits
# 2022-07-18 15:31:57,427 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00002_mirimage_fixed_cal.fits
# 2022-07-18 15:31:58,055 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00004_mirimage_fixed_cal.fits
# 2022-07-18 15:31:58,691 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00008_mirimage_fixed_cal.fits
# 2022-07-18 15:31:59,389 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00001_mirimage_fixed_cal.fits
# 2022-07-18 15:32:00,022 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00005_mirimage_fixed_cal.fits
# 2022-07-18 15:32:00,681 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00007_mirimage_fixed_cal.fits
# 2022-07-18 15:32:01,314 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00005_mirimage_fixed_cal.fits
# 2022-07-18 15:32:01,970 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00007_mirimage_fixed_cal.fits
# 2022-07-18 15:32:02,575 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002001_02103_00006_mirimage_fixed_cal.fits
# 2022-07-18 15:32:03,251 - stpipe.Image2Pipeline - INFO - Saved model in ./F1130W/stage2/jw02733002002_02103_00004_mirimage_fixed_cal.fits
# 2022-07-18 15:32:03,252 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}1*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# update the WCS for mosaic tile 2
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}2*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile2_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F1130W/stage2/jw02733002002_02103_00002_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00007_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00004_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00007_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00008_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00008_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00001_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00003_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00005_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00002_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00005_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00006_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00001_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00003_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002002_02103_00004_mirimage_fixed_wcs_cal.fits', './F1130W/stage2/jw02733002001_02103_00006_mirimage_fixed_wcs_cal.fits']
# miri_F1130W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-07-18 15:32:31,689 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-07-18 15:32:31,690 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-07-18 15:32:31,691 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-07-18 15:32:31,692 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-07-18 15:32:31,692 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-07-18 15:32:31,693 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-07-18 15:32:31,694 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-07-18 15:32:31,695 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-07-18 15:32:31,695 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-07-18 15:32:31,696 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-07-18 15:32:31,697 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-07-18 15:32:31,698 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-07-18 15:32:31,698 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-07-18 15:32:31,955 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1130W_stage3_asn.json',).
# 2022-07-18 15:32:31,961 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1130W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 3.3, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [151.75705520150103, -40.436433360520084], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-07-18 15:32:32,155 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02733002002_02103_00002_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-07-18 15:32:32,172 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-07-18 15:32:32,174 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-07-18 15:32:32,176 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-07-18 15:32:32,177 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-07-18 15:32:36,576 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-07-18 15:32:36,577 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 3.3, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-07-18 15:32:36,578 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-07-18 15:32:36,607 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-07-18 15:32:36,864 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-07-18 15:32:36,866 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-07-18 15:32:36,866 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-07-18 15:32:36,895 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-07-18 15:32:37,153 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-07-18 15:32:37,154 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-07-18 15:32:37,161 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 16 inputs
# 2022-07-18 15:32:38,169 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:39,254 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:40,340 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:41,431 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:42,527 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:43,621 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:44,713 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:45,816 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:46,910 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:48,011 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:49,118 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:50,206 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:51,283 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:52,376 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:53,528 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:54,667 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1163, 1734)
# 2022-07-18 15:32:56,362 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 16 images
# 2022-07-18 15:32:57,743 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-07-18 15:32:58,510 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:32:59,344 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:00,211 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:01,074 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:01,940 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:02,811 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:03,682 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:04,554 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:05,429 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:06,300 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:07,196 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:08,091 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:08,984 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:09,919 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:10,827 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:11,715 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1163, 1734)
# 2022-07-18 15:33:11,755 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-07-18 15:33:11,880 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 687 (0.07%)
# 2022-07-18 15:33:12,015 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 553 (0.05%)
# 2022-07-18 15:33:12,161 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 974 (0.09%)
# 2022-07-18 15:33:12,286 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers:
Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  151.713785059 -40.452456758 151.752443994 -40.472938710 151.792551212 -40.429069144 151.753905275 -40.408600549
# 2022-07-18 15:34:36,150 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1130W/stage3/miri_F1130W_stage3_asn_i2d.fits
# 2022-07-18 15:34:36,151 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-07-18 15:34:36,435 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1173, 1749) from miri_F1130W_stage3_asn_i2d.fits>,).
# 2022-07-18 15:34:36,436 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-07-18 15:34:36,455 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-07-18 15:34:36,466 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-07-18 15:34:36,466 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-07-18 15:34:36,467 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-07-18 15:34:36,467 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1130W
# 2022-07-18 15:34:36,467 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-07-18 15:34:36,549 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 5.49349
# 2022-07-18 15:34:36,636 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1173, 1749).
# 2022-07-18 15:34:36,960 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 42 sources
# 2022-07-18 15:34:37,273 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1130W/stage3/miri_F1130W_stage3_asn_cat.ecsv
# 2022-07-18 15:34:37,583 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1130W/stage3/miri_F1130W_stage3_asn_segm.fits
# 2022-07-18 15:34:37,584 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1130W_stage3_asn_segm.fits
# 2022-07-18 15:34:37,585 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-07-18 15:34:37,587 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
