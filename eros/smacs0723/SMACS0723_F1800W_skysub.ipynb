# %% [markdown]
# ## F1800W - SMACS0723 - skysub
#
# Author: Karl Gordon
#
# Last modified: 10 Aug 2022

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1800W"
fwhm = 5.2
exclude_above = None
ds9regions = None
exclude_delta = 1.0

crval = [110.8261940446365, -73.45398878295636]
# rotation = 63.0
# crval = None
rotation = None

tweakreg = False
align_to_gaia = False

matchbkg = False
scalebkg = False

# display range for images
drange_cal = [-0.1, 5.0]
dmap = "afmhot"  # same as ds9 bb

run_cc_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii, fits
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-pub.stsci.edu"

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image
from helpers.miri_clean import make_sky
from helpers.miri_helpers import miri_image3

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %% [markdown]
# ## Make a sky and subtract it

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_wcs_cal.fits")
simage = make_sky(miri_cal_files, exclude_above=exclude_above, ds9regions=ds9regions, 
                  exclude_delta=exclude_delta, scalebkg=scalebkg)
# Out:
# processing ./F1800W/stage2/jw02736002001_02107_00005_mirimage_fixed_wcs_cal.fits
# median sky = 89.22372436523438
# processing ./F1800W/stage2/jw02736002001_02107_00001_mirimage_fixed_wcs_cal.fits
# median sky = 89.29293823242188
# processing ./F1800W/stage2/jw02736002001_02107_00010_mirimage_fixed_wcs_cal.fits
# median sky = 89.17333221435547
# processing ./F1800W/stage2/jw02736002001_02107_00008_mirimage_fixed_wcs_cal.fits
# median sky = 89.19730377197266
# processing ./F1800W/stage2/jw02736002001_02107_00003_mirimage_fixed_wcs_cal.fits
# median sky = 89.25619506835938
# processing ./F1800W/stage2/jw02736002001_02107_00009_mirimage_fixed_wcs_cal.fits
# median sky = 89.18268585205078
# processing ./F1800W/stage2/jw02736002001_02107_00004_mirimage_fixed_wcs_cal.fits
# median sky = 89.2352523803711
# processing ./F1800W/stage2/jw02736002001_02107_00002_mirimage_fixed_wcs_cal.fits
# median sky = 89.26744079589844
# processing ./F1800W/stage2/jw02736002001_02107_00007_mirimage_fixed_wcs_cal.fits
# median sky = 89.20301055908203
# processing ./F1800W/stage2/jw02736002001_02107_00006_mirimage_fixed_wcs_cal.fits
# 2022-08-10 14:07:11,690 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:348: AstropyUserWarning: Input data contains invalid values (NaNs or infs), which were automatically clipped.
#   warnings.warn('Input data contains invalid values (NaNs or '
# median sky = 89.21467590332031
# Not scaling individual images to median bkg
# 2022-08-10 14:07:12,307 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:957: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2022-08-10 14:07:12,995 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1218: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
#
# 2022-08-10 14:07:13,344 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ./F1800W/stage2/jw02736002001_02107_00005_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00001_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00010_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00008_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00003_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00009_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00004_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00002_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00007_mirimage_fixed_wcs_cal.fits
# ./F1800W/stage2/jw02736002001_02107_00006_mirimage_fixed_wcs_cal.fits

# %%
show_image(simage, 39, 45., dmap=dmap)
fits.writeto(f"./{filter}/stage3/{filter}_sky.fits", simage, overwrite=True)

# %% [markdown]
# ### rerun CALWEBB_IMAGE3 with the new cleaned files

# %%
if run_cc_image3:
    miri_cccal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_wcs_skysub_cal.fits")
    output_dir = f"./{filter}/stage3/"
    print(miri_cccal_files)

    if rotation is not None:
        miri_asn_name = f'miri_{filter}_stage3_nirproj_asn_skysub'
    else: 
        miri_asn_name = f'miri_{filter}_stage3_asn_skysub'    
    miri_asn = asn_from_list.asn_from_list(miri_cccal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

    miri_asn_file = f'{miri_asn_name}.json'
    with open(miri_asn_file, 'w') as outfile:
        name, serialized = miri_asn.dump(format='json')
        outfile.write(serialized)
# Out:
# ['./F1800W/stage2/jw02736002001_02107_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00007_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00009_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00008_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00006_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00010_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00004_mirimage_fixed_wcs_skysub_cal.fits', './F1800W/stage2/jw02736002001_02107_00005_mirimage_fixed_wcs_skysub_cal.fits']

# %%
if run_cc_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg,
                crval=crval, rotation=rotation,
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-08-10 14:07:26,827 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-08-10 14:07:26,828 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 14:07:26,829 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-08-10 14:07:26,830 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-08-10 14:07:26,831 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-08-10 14:07:26,832 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-08-10 14:07:26,832 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-08-10 14:07:26,833 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-08-10 14:07:26,834 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-08-10 14:07:26,835 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-08-10 14:07:26,835 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-08-10 14:07:26,836 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-08-10 14:07:26,837 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-08-10 14:07:26,958 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1800W_stage3_asn_skysub.json',).
# 2022-08-10 14:07:26,963 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1800W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 5.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-08-10 14:07:27,145 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02107_00003_mirimage_fixed_wcs_skysub_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-08-10 14:07:27,468 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-08-10 14:07:27,470 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-08-10 14:07:27,472 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 14:07:27,474 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-08-10 14:07:30,026 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-08-10 14:07:30,028 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 5.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-08-10 14:07:30,028 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-08-10 14:07:30,047 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-08-10 14:07:30,188 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-08-10 14:07:30,190 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1
- stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:17,657 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:18,630 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:19,615 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:20,574 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:21,555 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:22,555 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:23,535 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:24,509 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:25,496 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:25,853 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-08-10 14:08:26,472 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:27,444 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:28,418 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:29,396 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:30,370 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:31,345 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:32,315 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:33,282 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:34,253 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:35,222 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:35,577 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-08-10 14:08:36,199 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:37,174 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:38,147 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:39,114 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:40,084 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:41,055 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:42,031 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:43,000 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:43,968 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:44,942 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 14:08:45,321 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.730883672 -73.445839196 110.776518771 -73.478719008 110.888942778 -73.466034875 110.843124792 -73.433179533
# 2022-08-10 14:08:46,296 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1800W/stage3/miri_F1800W_stage3_asn_skysub_i2d.fits
# 2022-08-10 14:08:46,296 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-08-10 14:08:46,461 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1157, 1126) from miri_F1800W_stage3_asn_skysub_i2d.fits>,).
# 2022-08-10 14:08:46,462 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-08-10 14:08:46,480 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-08-10 14:08:46,490 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-08-10 14:08:46,490 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-08-10 14:08:46,490 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-08-10 14:08:46,491 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1800W
# 2022-08-10 14:08:46,491 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-08-10 14:08:46,570 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 6.22752
# 2022-08-10 14:08:46,643 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1157, 1126).
# 2022-08-10 14:08:46,845 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 80 sources
# 2022-08-10 14:08:47,079 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1800W/stage3/miri_F1800W_stage3_asn_skysub_cat.ecsv
# 2022-08-10 14:08:47,319 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1800W/stage3/miri_F1800W_stage3_asn_skysub_segm.fits
# 2022-08-10 14:08:47,320 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1800W_stage3_asn_skysub_segm.fits
# 2022-08-10 14:08:47,321 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-08-10 14:08:47,323 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
drange = drange_cal
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)
