# %% [markdown]
# ## JWST F770W SMACS0723 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 8 Aug 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F770W"
fwhm = 2.2
basename = "jw0273600200"

crval = [110.8261940446365, -73.45398878295636]
# rotation = 63.0
# crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
#tile1_shifts = [0.0, 0.0]
#tweakreg = True
#align_to_gaia = True
tile1_shifts = [0.006003914950907428, -1.6397513463822861]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [17., 50.]
# display range for calibrated images
drange_cal = [5., 40.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = False
run_image2 = False
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev2+g6262cda

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F770W/stage0/jw02736002001_02101_00002_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00009_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00003_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00010_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00006_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00008_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00007_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00005_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00001_mirimage_uncal.fits', './F770W/stage0/jw02736002001_02101_00004_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F770W/stage1/jw02736002001_02101_00005_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00004_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00010_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00008_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00001_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00002_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00003_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00006_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00007_mirimage_fixed_rate.fits', './F770W/stage1/jw02736002001_02101_00009_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}1*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F770W/stage2/jw02736002001_02101_00009_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00006_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00005_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00008_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00010_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00002_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00001_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00004_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00003_mirimage_fixed_wcs_cal.fits', './F770W/stage2/jw02736002001_02101_00007_mirimage_fixed_wcs_cal.fits']
# miri_F770W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-08-10 10:14:32,930 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-08-10 10:14:32,932 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 10:14:32,934 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-08-10 10:14:32,937 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-08-10 10:14:32,938 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-08-10 10:14:32,941 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-08-10 10:14:32,942 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-08-10 10:14:32,945 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-08-10 10:14:32,946 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-08-10 10:14:32,948 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-08-10 10:14:32,950 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-08-10 10:14:32,951 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-08-10 10:14:32,952 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-08-10 10:14:33,236 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F770W_stage3_asn.json',).
# 2022-08-10 10:14:33,245 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F770W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-08-10 10:14:33,540 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02101_00009_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-08-10 10:14:33,854 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-08-10 10:14:33,856 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-08-10 10:14:33,858 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 10:14:33,860 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-08-10 10:14:37,328 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-08-10 10:14:37,331 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.2, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-08-10 10:14:37,331 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-08-10 10:14:37,376 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-08-10 10:14:37,694 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-08-10 10:14:37,696 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-08-10 10:14:37,697 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-08-10 10:14:37,742 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-08-10 10:14:38,050 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-08-10 10:14:38,052 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-08-10 10:14:38,065 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 10 inputs
# 2022-08-10 10:14:39,655 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:40,943 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:42,442 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:44,101 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:45,804 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:47,628 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:49,186 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:50,924 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:52,257 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:53,485 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 10:14:54,983 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 10 images
# 2022-08-10 10:14:56,195 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-08-10 10:14:57,408 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:14:58,520 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:14:59,616 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:00,698 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:01,765 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:02,903 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:04,066 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:05,204 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:06,592 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:07,776 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 10:15:07,812 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-08-10 10:15:07,919 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 6325 (0.60%)
# 2022-08-10 10:15:08,022 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 5148 (0.49%)
# 2022-08-10 10:15:08,124 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 6623 (0.63%)
# 2022-08-10 10:15:08,230 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4701 (0.44%)
# 2022-08-10 10:15:08,344 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 5388 (0.51%)
# 2022-08-10 10:15:08,450 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 5429 (0.51%)
# 2022-08-10 10:15:08,561 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 9020 (0.85%)
# 2022-08-10 10:15:08,698 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 5916 (0.56%)
# 2022-08-10 10:15:08,837 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 4486 (0.42%)
# 2022-08-10 10:15:08,972 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 6417 (0.61%)
# 2022-08-10 10:15:10,170 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00009_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:11,222 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00006_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:12,264 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00005_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:13,308 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00008_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:14,903 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00010_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:16,059 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:17,308 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:18,404 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:19,508 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:20,618 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F770W/stage3/jw02736002001_02101_00007_mirimage_fixed_wcs_a3001_crf.fits
# 2022-08-10 10:15:20,619 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-08-10 10:15:20,855 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-08-10 10:15:20,857 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}
# 2022-08-10 10:15:20,876 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-08-10 10:15:21,153 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for miri_F770W_stage3_asn
# 2022-08-10 10:15:22,046 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-08-10 10:15:22,845 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:23,884 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:24,948 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:25,957 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:26,969 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:28,001 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:29,170 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:30,554 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:31,904 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:33,248 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:33,677 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-08-10 10:15:34,287 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:35,293 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:36,290 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:37,265 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:38,277 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:39,271 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:40,234 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:41,205 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:42,183 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:43,150 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:43,491 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-08-10 10:15:44,123 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:45,093 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:46,076 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:47,063 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:48,087 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:49,032 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:49,990 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:50,949 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:51,918 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:52,869 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:53,210 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-08-10 10:15:53,836 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:54,818 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:55,775 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:56,731 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:57,695 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:58,641 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:15:59,590 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:16:00,534 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:16:01,528 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:16:02,481 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:16:02,845 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.730874727 -73.445865639 110.776516269 -73.478744734 110.888937979 -73.466058836 110.843113568 -73.433204213
# 2022-08-10 10:16:03,911 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F770W/stage3/miri_F770W_stage3_asn_i2d.fits
# 2022-08-10 10:16:03,911 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-08-10 10:16:04,104 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1157, 1126) from miri_F770W_stage3_asn_i2d.fits>,).
# 2022-08-10 10:16:04,106 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-08-10 10:16:04,121 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-08-10 10:16:04,131 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-08-10 10:16:04,131 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-08-10 10:16:04,132 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-08-10 10:16:04,132 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F770W
# 2022-08-10 10:16:04,132 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-08-10 10:16:04,205 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.38398
# 2022-08-10 10:16:04,271 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1157, 1126).
# 2022-08-10 10:16:04,469 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 89 sources
# 2022-08-10 10:16:04,752 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F770W/stage3/miri_F770W_stage3_asn_cat.ecsv
# 2022-08-10 10:16:05,008 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F770W/stage3/miri_F770W_stage3_asn_segm.fits
# 2022-08-10 10:16:05,009 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F770W_stage3_asn_segm.fits
# 2022-08-10 10:16:05,010 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-08-10 10:16:05,011 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
