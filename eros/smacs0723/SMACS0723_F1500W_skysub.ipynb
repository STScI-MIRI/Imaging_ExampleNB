# %% [markdown]
# ## F1500W - SMACS0723 - skysub
#
# Author: Karl Gordon
#
# Last modified: 10 Aug 2022

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1500W"
fwhm = 4.4
exclude_above = None
ds9regions = None
exclude_delta = 1.0

crval = [110.8261940446365, -73.45398878295636]
# rotation = 63.0
# crval = None
rotation = None

tweakreg = False
align_to_gaia = False

matchbkg = False
scalebkg = False

# display range for images
drange_cal = [-0.1, 5.0]
dmap = "afmhot"  # same as ds9 bb

run_cc_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii, fits
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-pub.stsci.edu"

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image
from helpers.miri_clean import make_sky
from helpers.miri_helpers import miri_image3

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %% [markdown]
# ## Make a sky and subtract it

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_wcs_cal.fits")
simage = make_sky(miri_cal_files, exclude_above=exclude_above, ds9regions=ds9regions, 
                  exclude_delta=exclude_delta, scalebkg=scalebkg)
# Out:
# processing ./F1500W/stage2/jw02736002001_02105_00009_mirimage_fixed_wcs_cal.fits
# median sky = 39.60129165649414
# processing ./F1500W/stage2/jw02736002001_02105_00007_mirimage_fixed_wcs_cal.fits
# median sky = 39.61609649658203
# processing ./F1500W/stage2/jw02736002001_02105_00008_mirimage_fixed_wcs_cal.fits
# median sky = 39.61360168457031
# processing ./F1500W/stage2/jw02736002001_02105_00004_mirimage_fixed_wcs_cal.fits
# median sky = 39.63212966918945
# processing ./F1500W/stage2/jw02736002001_02105_00001_mirimage_fixed_wcs_cal.fits
# median sky = 39.57262420654297
# processing ./F1500W/stage2/jw02736002001_02105_00006_mirimage_fixed_wcs_cal.fits
# median sky = 39.620361328125
# processing ./F1500W/stage2/jw02736002001_02105_00003_mirimage_fixed_wcs_cal.fits
# median sky = 39.63462829589844
# processing ./F1500W/stage2/jw02736002001_02105_00002_mirimage_fixed_wcs_cal.fits
# median sky = 39.636417388916016
# processing ./F1500W/stage2/jw02736002001_02105_00005_mirimage_fixed_wcs_cal.fits
# median sky = 39.623390197753906
# processing ./F1500W/stage2/jw02736002001_02105_00010_mirimage_fixed_wcs_cal.fits
# 2022-08-10 13:10:37,217 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:348: AstropyUserWarning: Input data contains invalid values (NaNs or infs), which were automatically clipped.
#   warnings.warn('Input data contains invalid values (NaNs or '
# median sky = 39.60041427612305
# Not scaling individual images to median bkg
# 2022-08-10 13:10:37,761 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:957: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2022-08-10 13:10:38,364 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1218: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
#
# 2022-08-10 13:10:38,621 - stpipe - WARNING - /user/kgordon/anaconda3/envs/jwstdev/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ./F1500W/stage2/jw02736002001_02105_00009_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00007_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00008_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00004_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00001_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00006_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00003_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00002_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00005_mirimage_fixed_wcs_cal.fits
# ./F1500W/stage2/jw02736002001_02105_00010_mirimage_fixed_wcs_cal.fits

# %%
show_image(simage, 39, 45., dmap=dmap)
fits.writeto(f"./{filter}/stage3/{filter}_sky.fits", simage, overwrite=True)

# %% [markdown]
# ### rerun CALWEBB_IMAGE3 with the new cleaned files

# %%
if run_cc_image3:
    miri_cccal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_wcs_skysub_cal.fits")
    output_dir = f"./{filter}/stage3/"
    print(miri_cccal_files)

    if rotation is not None:
        miri_asn_name = f'miri_{filter}_stage3_nirproj_asn_skysub'
    else: 
        miri_asn_name = f'miri_{filter}_stage3_asn_skysub'    
    miri_asn = asn_from_list.asn_from_list(miri_cccal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

    miri_asn_file = f'{miri_asn_name}.json'
    with open(miri_asn_file, 'w') as outfile:
        name, serialized = miri_asn.dump(format='json')
        outfile.write(serialized)
# Out:
# ['./F1500W/stage2/jw02736002001_02105_00008_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00007_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00010_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00009_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00006_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00003_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00004_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00002_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00001_mirimage_fixed_wcs_skysub_cal.fits', './F1500W/stage2/jw02736002001_02105_00005_mirimage_fixed_wcs_skysub_cal.fits']

# %%
if run_cc_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg,
                crval=crval, rotation=rotation,
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-08-10 13:10:52,130 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-08-10 13:10:52,132 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 13:10:52,133 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-08-10 13:10:52,135 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-08-10 13:10:52,136 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-08-10 13:10:52,138 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-08-10 13:10:52,139 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-08-10 13:10:52,141 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-08-10 13:10:52,142 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-08-10 13:10:52,144 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-08-10 13:10:52,144 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-08-10 13:10:52,146 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-08-10 13:10:52,147 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-08-10 13:10:52,368 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1500W_stage3_asn_skysub.json',).
# 2022-08-10 13:10:52,374 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1500W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 4.4, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-08-10 13:10:52,625 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02105_00008_mirimage_fixed_wcs_skysub_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-08-10 13:10:53,058 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-08-10 13:10:53,060 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-08-10 13:10:53,062 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 13:10:53,065 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-08-10 13:10:56,479 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-08-10 13:10:56,482 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 4.4, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False
- stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:50,453 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:51,461 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:52,468 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:53,476 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:53,863 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-08-10 13:11:54,487 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:55,495 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:56,504 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:57,526 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:58,525 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:11:59,531 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:00,561 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:01,586 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:02,579 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:03,575 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:03,963 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-08-10 13:12:04,575 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:05,574 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:06,579 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:07,578 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:08,575 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:09,593 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:10,613 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:11,617 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:12,613 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:13,613 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 13:12:14,035 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.730809862 -73.445847957 110.776446739 -73.478727571 110.888870124 -73.466042952 110.843050365 -73.433187808
# 2022-08-10 13:12:15,028 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1500W/stage3/miri_F1500W_stage3_asn_skysub_i2d.fits
# 2022-08-10 13:12:15,028 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-08-10 13:12:15,204 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1157, 1126) from miri_F1500W_stage3_asn_skysub_i2d.fits>,).
# 2022-08-10 13:12:15,205 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-08-10 13:12:15,220 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-08-10 13:12:15,230 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-08-10 13:12:15,230 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-08-10 13:12:15,231 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-08-10 13:12:15,231 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1500W
# 2022-08-10 13:12:15,231 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-08-10 13:12:15,305 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 5.83929
# 2022-08-10 13:12:15,383 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1157, 1126).
# 2022-08-10 13:12:15,585 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 102 sources
# 2022-08-10 13:12:15,870 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1500W/stage3/miri_F1500W_stage3_asn_skysub_cat.ecsv
# 2022-08-10 13:12:16,106 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1500W/stage3/miri_F1500W_stage3_asn_skysub_segm.fits
# 2022-08-10 13:12:16,107 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1500W_stage3_asn_skysub_segm.fits
# 2022-08-10 13:12:16,108 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-08-10 13:12:16,109 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
drange = drange_cal
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)
