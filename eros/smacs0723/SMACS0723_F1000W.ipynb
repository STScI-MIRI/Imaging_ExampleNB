# %% [markdown]
# ## JWST F1000W SMACS0723 ERO
#
# Data is setup in a subdirectory that is given in the filter variable below (i.e., "F560W"). Inside this directory, there should be 4 subdirectories called stage0, stage1, stage2, and stage3. The uncal (raw) fits files should be in the stage0 directory.
#
# Author: Karl Gordon
#
# Last modified: 10 Aug 2022
#
# Based on JWebbinar notebooks by Bryan Hilbert, MIRI simulated notebooks by Mattia Libralato, input from various MIRI team members, and input from the jwst pipeline developers.
#
# Uses custom code given in helpers subdirectory.
#
# Extensively tested on MIRI ERO mosaics.

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1000W"
fwhm = 2.9
basename = "jw0273600200"

crval = [110.8261940446365, -73.45398878295636]
# rotation = 63.0
# crval = None
rotation = None

# shifts determine from previous runs with treakreg or with other filters
#   analysis using Analyze_teakreg_shifts.ipynb
#   run this notebook after running shortest wavelength dataset with tweakreg=True and align_to_gaia=True
#     and setting all the tile?_shifts to [0.0, 0.0]
#   use the resulting shifts here and set tweakreg=False and align_to_gaia=False
#tile1_shifts = [0.0, 0.0]
#tweakreg = True
#align_to_gaia = True
tile1_shifts = [0.006003914950907428, -1.6397513463822861]
tweakreg = False
align_to_gaia = False

# only needed if multiple datasets combined that are taken separately (e.g., weeks apart)
matchbkg = False

# display range for uncalibrated images
drange_raw = [17., 50.]
# display range for calibrated images
drange_cal = [5., 40.]
dmap = "afmhot"  # same as ds9 bb

# specify the linearity file to use if default not desired
# linfile = ""
linfile = None

# specify the flat file to use if default not desired
flatfile = None

run_detector1 = True
run_image2 = True
run_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image, overlay_catalog
from helpers.miri_helpers import miri_detector1, miri_image2, miri_image3
from helpers.miri_clean import fix_rateints_to_rate, shift_cal_wcs

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %%
import stcal
print(stcal.__version__)
# Out:
# 1.0.1.dev2+g6262cda

# %%
# create stage directories if they do not exist
for k in range(4):
    cpath = f"./{filter}/stage{k}"
    if not os.path.exists(cpath):
        os.makedirs(cpath)

# %% [markdown]
# ## CALWEBB_DETECTOR1

# %%
miri_uncal_files = glob.glob(f"./{filter}/stage0/*uncal.fits")
output_dir = f'./{filter}/stage1'
print(miri_uncal_files)
# Out:
# ['./F1000W/stage0/jw02736002001_02103_00007_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00003_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00008_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00001_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00009_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00006_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00005_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00010_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00004_mirimage_uncal.fits', './F1000W/stage0/jw02736002001_02103_00002_mirimage_uncal.fits']

# %%
if run_detector1:
    miri_detector1(miri_uncal_files, output_dir, linfile=linfile)
# Out:
# 2022-08-10 10:13:12,906 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2022-08-10 10:13:12,907 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,907 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2022-08-10 10:13:12,908 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_mask': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,909 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2022-08-10 10:13:12,909 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'n_pix_grow_sat': 1, 'override_saturation': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,910 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2022-08-10 10:13:12,911 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_ipc': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,911 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2022-08-10 10:13:12,912 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,912 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-08-10 10:13:12,913 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,913 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2022-08-10 10:13:12,914 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'type': 'baseline', 'override_rscd': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,914 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2022-08-10 10:13:12,915 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,916 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2022-08-10 10:13:12,916 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,917 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2022-08-10 10:13:12,917 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_linearity': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,918 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2022-08-10 10:13:12,918 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'dark_output': None, 'override_dark': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,919 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2022-08-10 10:13:12,920 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_reset': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,920 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2022-08-10 10:13:12,921 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True, 'override_trapdensity': None, 'override_trappars': None, 'override_persat': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,921 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2022-08-10 10:13:12,922 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'override_gain': None, 'override_readnoise': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,923 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2022-08-10 10:13:12,923 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'none', 'override_readnoise': None, 'override_gain': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,924 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2022-08-10 10:13:12,925 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_gain': None, 'class': ''}
#
#
# 2022-08-10 10:13:12,925 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# ./F1000W/stage0/jw02736002001_02103_00007_mirimage_uncal.fits
# 2022-08-10 10:13:13,002 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('./F1000W/stage0/jw02736002001_02103_00007_mirimage_uncal.fits',).
# 2022-08-10 10:13:13,011 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_ ...
# 2022-08-10 10:13:20,617 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02103_00007_mirimage_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 
- stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2022-08-10 10:13:56,610 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2022-08-10 10:13:57,191 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 100, 1024, 1032) from jw02736002001_02103_00007_mirimage_uncal.fits>,).
# 2022-08-10 10:13:57,192 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-08-10 10:13:58,261 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2022-08-10 10:13:58,262 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2022-08-10 10:13:58,262 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2022-08-10 10:13:58,262 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2022-08-10 10:13:58,263 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2022-08-10 10:13:58,263 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2022-08-10 10:13:58,263 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2022-08-10 10:13:58,263 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2022-08-10 10:13:58,265 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2022-08-10 10:14:00,840 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2022-08-10 10:14:01,066 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2022-08-10 10:14:01,302 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 100, 1024, 1032) from jw02736002001_02103_00007_mirimage_uncal.fits>,).
# 2022-08-10 10:14:01,303 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'rejection_threshold': 5.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-08-10 10:14:01,312 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2022-08-10 10:14:01,313 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2022-08-10 10:14:01,327 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-08-10 10:14:01,373 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-08-10 10:14:02,842 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2022-08-10 10:14:03,329 - stpipe.Detector1Pipeline.jump - INFO - Creating 10 processes for jump detection
# 2022-08-10 10:14:04,564 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:04,872 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:05,186 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:05,503 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:05,635 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:05,647 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 9447 pixels with at least one CR from five groups.
# 2022-08-10 10:14:05,648 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:05,649 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-08-10 10:14:05,818 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:05,991 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 7964 pixels with at least one CR from five groups.
# 2022-08-10 10:14:05,992 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:05,993 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:06,138 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:06,309 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 7748 pixels with at least one CR from five groups.
# 2022-08-10 10:14:06,310 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:06,311 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:06,466 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:06,611 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:06,623 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8034 pixels with at least one CR from five groups.
# 2022-08-10 10:14:06,624 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-08-10 10:14:06,625 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:06,803 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:06,950 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:06,936 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:06,948 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8954 pixels with at least one CR from five groups.
# 2022-08-10 10:14:06,949 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-08-10 10:14:07,270 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8232 pixels with at least one CR from five groups.
# 2022-08-10 10:14:07,271 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:07,271 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:07,287 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:07,606 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:14:07,666 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:07,682 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8358 pixels with at least one CR from five groups.
# 2022-08-10 10:14:07,684 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:07,685 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:08,350 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:14:08,358 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:08,373 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8912 pixels with at least one CR from five groups.
# 2022-08-10 10:14:08,375 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:08,375 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 3 pixels with at least one CR from three groups.
# 2022-08-10 10:14:08,410 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:08,422 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8529 pixels with at least one CR from five groups.
# 2022-08-10 10:14:08,423 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:14:08,424 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:08,613 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:14:08,631 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:14:08,735 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:14:08,747 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 9510 pixels with at least one CR from five groups.
# 2022-08-10 10:14:08,748 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-08-10 10:14:08,749 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:14:08,982 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:14:09,156 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:14:09,169 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:14:09,548 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 
- stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'override_superbias': None, 'class': ''}
#
#
# 2022-08-10 10:16:03,442 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2022-08-10 10:16:03,443 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'override_refpix': None, 'class': ''}
#
#
# 2022-08-10 10:16:03,443 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# ...
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:37:52,540 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8530 pixels with at least one CR from five groups.
# 2022-08-10 10:37:52,541 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:52,542 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:52,549 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:37:52,880 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:37:53,041 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:53,023 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:37:53,039 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8838 pixels with at least one CR from five groups.
# 2022-08-10 10:37:53,040 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:53,334 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2022-08-10 10:37:53,463 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:37:53,485 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8958 pixels with at least one CR from five groups.
# 2022-08-10 10:37:53,486 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:53,488 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:53,720 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:37:53,732 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8726 pixels with at least one CR from five groups.
# 2022-08-10 10:37:53,733 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:53,734 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-08-10 10:37:54,210 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:37:54,226 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 9142 pixels with at least one CR from five groups.
# 2022-08-10 10:37:54,228 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:54,229 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:54,832 - stpipe.Detector1Pipeline.jump - WARNING - /user/kgordon/Python/stcal/src/stcal/jump/twopoint_difference.py:128: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-08-10 10:37:54,848 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 10698 pixels with at least one CR from five groups.
# 2022-08-10 10:37:54,849 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-08-10 10:37:54,850 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# 2022-08-10 10:37:54,998 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:55,145 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:55,366 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:55,674 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:56,097 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8089 pixels with at least one CR from five groups.
# 2022-08-10 10:37:56,098 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 1 pixels with at least one CR from four groups.
# 2022-08-10 10:37:56,099 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:56,192 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8597 pixels with at least one CR from five groups.
# 2022-08-10 10:37:56,193 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:56,193 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:56,429 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:56,442 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8605 pixels with at least one CR from five groups.
# 2022-08-10 10:37:56,443 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:56,443 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:56,660 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 9317 pixels with at least one CR from five groups.
# 2022-08-10 10:37:56,661 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:56,662 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:57,188 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:57,539 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8361 pixels with at least one CR from five groups.
# 2022-08-10 10:37:57,541 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:57,541 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:58,109 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8498 pixels with at least one CR from five groups.
# 2022-08-10 10:37:58,111 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:58,111 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:58,124 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:59,018 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:37:59,124 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8901 pixels with at least one CR from five groups.
# 2022-08-10 10:37:59,125 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:59,126 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:37:59,948 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 10504 pixels with at least one CR from five groups.
# 2022-08-10 10:37:59,949 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:37:59,950 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:38:00,039 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:38:00,336 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2022-08-10 10:38:00,935 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 8062 pixels with at least one CR from five groups.
# 2022-08-10 10:38:00,936 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:38:00,937 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:38:01,286 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 10867 pixels with at least one CR from five groups.
# 2022-08-10 10:38:01,287 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from four groups.
# 2022-08-10 10:38:01,288 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-08-10 10:38:06,019 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 17.9991 sec
# 2022-08-10 10:38:06,081 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 19.503168
# 2022-08-10 10:38:06,086 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2022-08-10 10:38:06,355 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 100, 1024, 1032) from jw02736002001_02103_00002_mirimage_uncal.fits>,).
# 2022-08-10 10:38:06,357 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage1', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': './F1000W/stage0', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2022-08-10 10:38:06,391 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2022-08-10 10:38:06,392 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0008.fits
# 2022-08-10 10:38:06,440 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2022-08-10 10:38:06,440 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2022-08-10 10:38:07,389 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2022-08-10 10:38:07,390 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2022-08-10 10:38:07,391 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 10
# 2022-08-10 10:39:03,720 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:03,723 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:10,708 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:10,710 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:15,656 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:15,658 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:18,603 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:18,605 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:19,913 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:19,915 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:20,029 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:20,031 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:21,204 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:21,206 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:22,792 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:22,793 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:41,025 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:41,027 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:41,119 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 98
# 2022-08-10 10:39:41,120 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2022-08-10 10:39:41,445 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2022-08-10 10:39:41,731 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02736002001_02103_00002_mirimage_uncal.fits>,).
# 2022-08-10 10:39:41,736 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-08-10 10:39:41,777 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-08-10 10:39:41,777 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-08-10 10:39:41,781 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-08-10 10:39:41,891 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw02736002001_02103_00002_mirimage_uncal.fits>,).
# 2022-08-10 10:39:41,892 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': './F1000W/stage0'}
# 2022-08-10 10:39:41,929 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2022-08-10 10:39:41,930 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2022-08-10 10:39:41,933 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2022-08-10 10:39:42,552 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1000W/stage1/jw02736002001_02103_00002_mirimage_rateints.fits
# 2022-08-10 10:39:42,552 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2022-08-10 10:39:42,553 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:39:42,922 - stpipe.Detector1Pipeline - INFO - Saved model in ./F1000W/stage1/jw02736002001_02103_00002_mirimage_rate.fits
# 2022-08-10 10:39:42,923 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# fix the making of the rate images from the rateints images
#   needed for multiple integrations in regions near saturation
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_rate.fits")
for cfile in miri_rate_files:
    fix_rateints_to_rate(cfile)

# %%
# look at one of the images
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
miri_rate = datamodels.open(miri_rate_files[0])
drange = drange_raw

# %%
show_image(miri_rate.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_rate_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_rate_files):
    with datamodels.open(cfile) as miri_rate:
        cimage = miri_rate.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE2

# %%
miri_rate_files = glob.glob(f"./{filter}/stage1/*ge_fixed_rate.fits")
output_dir = f'./{filter}/stage2'
print(miri_rate_files)
# Out:
# ['./F1000W/stage1/jw02736002001_02103_00006_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00007_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00005_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00009_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00010_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00008_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00004_mirimage_fixed_rate.fits']

# %%
if run_image2:
    miri_image2(miri_rate_files, output_dir, flatfile=flatfile)
# Out:
# 2022-08-10 10:39:58,369 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2022-08-10 10:39:58,370 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None, 'override_wfssbkg': None, 'override_wavelengthrange': None, 'class': ''}
#
#
# 2022-08-10 10:39:58,371 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-08-10 10:39:58,372 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55, 'override_distortion': None, 'override_filteroffset': None, 'override_specwcs': None, 'override_regions': None, 'override_wavelengthrange': None, 'override_camera': None, 'override_collimator': None, 'override_disperser': None, 'override_fore': None, 'override_fpa': None, 'override_msa': None, 'override_ote': None, 'override_ifupost': None, 'override_ifufore': None, 'override_ifuslicer': None, 'class': ''}
#
#
# 2022-08-10 10:39:58,372 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-08-10 10:39:58,373 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False, 'override_flat': None, 'override_fflat': None, 'override_sflat': None, 'override_dflat': None, 'class': ''}
#
#
# 2022-08-10 10:39:58,373 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-08-10 10:39:58,374 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'inverse': False, 'source_type': None, 'override_photom': None, 'override_area': None, 'class': ''}
#
#
# 2022-08-10 10:39:58,375 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-08-10 10:39:58,375 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-08-10 10:39:58,376 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2022-08-10 10:39:58,541 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args (['./F1000W/stage1/jw02736002001_02103_00006_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00007_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00002_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00001_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00005_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00009_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00003_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00010_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00008_mirimage_fixed_rate.fits', './F1000W/stage1/jw02736002001_02103_00004_mirimage_fixed_rate.fits'],).
# 2022-08-10 10:39:58,545 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage2', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# 2022-08-10 10:39:59,013 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02103_00006_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 10:39:59,026 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-08-10 10:39:59,038 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 10:39:59,039 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 10:39:59,039 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,039 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 10:39:59,039 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-08-10 10:39:59,041 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 10:39:59,042 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,043 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-08-10 10:39:59,044 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-08-10 10:39:59,046 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 10:39:59,047 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 10:39:59,047 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 10:39:59,047 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 10:39:59,048 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 10:39:59,048 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 10:39:59,048 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 10:39:59,048 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-08-10 10:39:59,050 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 10:39:59,050 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,050 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 10:39:59,051 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 10:39:59,051 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 10:39:59,052 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02103_00007_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 10:39:59,055 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-08-10 10:39:59,056 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 10:39:59,056 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 10:39:59,057 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,057 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 10:39:59,057 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-08-10 10:39:59,058 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 10:39:59,059 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,059 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf'.
# 2022-08-10 10:39:59,060 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_flat_0786.fits'.
# 2022-08-10 10:39:59,060 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 10:39:59,060 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 10:39:59,061 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 10:39:59,061 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 10:39:59,061 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 10:39:59,061 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 10:39:59,061 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 10:39:59,062 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits'.
# 2022-08-10 10:39:59,062 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 10:39:59,063 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,063 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 10:39:59,063 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 10:39:59,063 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 10:39:59,064 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02103_00002_mirimage_fixed_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 10:39:59,067 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2022-08-10 10:39:59,068 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 10:39:59,068 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 10:39:59,068 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 10:39:59,068 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 10:39:59,068 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2022-08-10
- stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:47,376 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2022-08-10 10:40:47,918 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:48,242 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2022-08-10 10:40:48,791 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:49,132 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.736028345 -73.447084631 110.776591185 -73.476279444 110.880163036 -73.464584113 110.839450625 -73.435409337
# 2022-08-10 10:40:49,695 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00008_mirimage_fixed_i2d.fits
# 2022-08-10 10:40:49,696 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2022-08-10 10:40:49,696 - stpipe.Image2Pipeline - INFO - Finished processing product ./F1000W/stage1/jw02736002001_02103_00008_mirimage_fixed
# 2022-08-10 10:40:49,697 - stpipe.Image2Pipeline - INFO - Processing product ./F1000W/stage1/jw02736002001_02103_00004_mirimage_fixed
# 2022-08-10 10:40:49,698 - stpipe.Image2Pipeline - INFO - Working on input ./F1000W/stage1/jw02736002001_02103_00004_mirimage_fixed_rate.fits ...
# 2022-08-10 10:40:49,929 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from jw02736002001_02103_00004_mirimage_fixed_rate.fits>,).
# 2022-08-10 10:40:49,931 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-08-10 10:40:50,130 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0006.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2022-08-10 10:40:50,223 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  110.738047182 -73.444730025 110.778795921 -73.473779070 110.881332408 -73.462131910 110.841314111 -73.432947901
# 2022-08-10 10:40:50,223 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  110.738047182 -73.444730025 110.778795921 -73.473779070 110.881332408 -73.462131910 110.841314111 -73.432947901
# 2022-08-10 10:40:50,223 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-08-10 10:40:50,289 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-08-10 10:40:50,461 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw02736002001_02103_00004_mirimage_fixed_rate.fits>,).
# 2022-08-10 10:40:50,462 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-08-10 10:40:50,553 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-08-10 10:40:50,554 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-08-10 10:40:50,554 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-08-10 10:40:50,560 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-08-10 10:40:50,687 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2022-08-10 10:40:50,860 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw02736002001_02103_00004_mirimage_fixed_rate.fits>,).
# 2022-08-10 10:40:50,861 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-08-10 10:40:50,883 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_photom_0074.fits
# 2022-08-10 10:40:50,883 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_area_0004.fits
# 2022-08-10 10:40:50,969 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2022-08-10 10:40:50,970 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2022-08-10 10:40:50,970 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2022-08-10 10:40:50,970 - stpipe.Image2Pipeline.photom - INFO -  filter: F1000W
# 2022-08-10 10:40:51,011 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2022-08-10 10:40:51,012 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2022-08-10 10:40:51,013 - stpipe.Image2Pipeline.photom - WARNING - Expected to find one matching row in table, found 0.
# 2022-08-10 10:40:51,013 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 0.369118
# 2022-08-10 10:40:51,029 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2022-08-10 10:40:51,196 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from jw02736002001_02103_00004_mirimage_fixed_rate.fits>,).
# 2022-08-10 10:40:51,198 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': False, 'allowed_memory': None}
# 2022-08-10 10:40:51,220 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-08-10 10:40:51,358 - stpipe.Image2Pipeline.resample - INFO - Resampling science data
# 2022-08-10 10:40:51,896 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:52,208 - stpipe.Image2Pipeline.resample - INFO - Resampling var_rnoise
# 2022-08-10 10:40:52,723 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:53,040 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2022-08-10 10:40:53,583 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:53,899 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2022-08-10 10:40:54,449 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2022-08-10 10:40:54,783 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.737832564 -73.444616440 110.778392172 -73.473810955 110.881947933 -73.462114866 110.841238805 -73.432940387
# 2022-08-10 10:40:55,384 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00004_mirimage_fixed_i2d.fits
# 2022-08-10 10:40:55,385 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2022-08-10 10:40:55,386 - stpipe.Image2Pipeline - INFO - Finished processing product ./F1000W/stage1/jw02736002001_02103_00004_mirimage_fixed
# 2022-08-10 10:40:55,387 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# 2022-08-10 10:40:55,387 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,388 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,388 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,388 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,388 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,388 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,389 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,389 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,389 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,389 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0942.pmap
# 2022-08-10 10:40:55,992 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00006_mirimage_fixed_cal.fits
# 2022-08-10 10:40:56,544 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00007_mirimage_fixed_cal.fits
# 2022-08-10 10:40:57,110 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00002_mirimage_fixed_cal.fits
# 2022-08-10 10:40:57,709 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00001_mirimage_fixed_cal.fits
# 2022-08-10 10:40:58,295 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00005_mirimage_fixed_cal.fits
# 2022-08-10 10:40:58,892 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00009_mirimage_fixed_cal.fits
# 2022-08-10 10:40:59,497 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00003_mirimage_fixed_cal.fits
# 2022-08-10 10:41:00,087 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00010_mirimage_fixed_cal.fits
# 2022-08-10 10:41:00,709 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00008_mirimage_fixed_cal.fits
# 2022-08-10 10:41:01,288 - stpipe.Image2Pipeline - INFO - Saved model in ./F1000W/stage2/jw02736002001_02103_00004_mirimage_fixed_cal.fits
# 2022-08-10 10:41:01,288 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
drange = drange_cal
# look at one of the images
miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_cal.fits")
miri_cal = datamodels.open(miri_cal_files[0])
show_image(miri_cal.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
show_image(miri_cal.dq, 0, 10, dmap=dmap)

# %%
# display the images
fig = plt.figure(1, figsize=(12, 12))
ncols = len(miri_cal_files) // 3
grid = ImageGrid(fig, 111, nrows_ncols=(ncols+1, 3), axes_pad=0)

for i, cfile in enumerate(miri_cal_files):
    with datamodels.open(cfile) as miri_cal:
        cimage = miri_cal.data
        norm_data = simple_norm(cimage, "sqrt", min_cut=drange[0], max_cut=drange[1])
        grid[i].imshow(cimage, norm=norm_data, origin="lower", cmap=plt.get_cmap(dmap))
        grid[i].axis('off')
        grid[i].set_xticks([])
        grid[i].set_yticks([])

# %% [markdown]
# ## CALWEBB_IMAGE3

# %%
# update the WCS for mosaic tile 1
miri_cal_files = glob.glob(f"./{filter}/stage2/{basename}1*ge_fixed_cal.fits")
for cfile in miri_cal_files:
    shift_cal_wcs(cfile, tile1_shifts)

# %%
miri_cal_files = glob.glob(f"./{filter}/stage2/j*ge_fixed_wcs_cal.fits")
output_dir = f"./{filter}/stage3/"
print(miri_cal_files)

if rotation is not None:
    miri_asn_name = f'miri_{filter}_stage3_fixedrot_asn'
else: 
    miri_asn_name = f'miri_{filter}_stage3_asn'
miri_asn = asn_from_list.asn_from_list(miri_cal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

miri_asn_file = f'{miri_asn_name}.json'
with open(miri_asn_file, 'w') as outfile:
    name, serialized = miri_asn.dump(format='json')
    outfile.write(serialized)
    
print(miri_asn_file)
# Out:
# ['./F1000W/stage2/jw02736002001_02103_00009_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00008_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00001_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00004_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00005_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00007_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00006_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00010_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00002_mirimage_fixed_wcs_cal.fits', './F1000W/stage2/jw02736002001_02103_00003_mirimage_fixed_wcs_cal.fits']
# miri_F1000W_stage3_asn.json

# %%
if run_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg, 
                crval=crval, rotation=rotation, 
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-08-10 10:41:17,277 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-08-10 10:41:17,278 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 10:41:17,278 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-08-10 10:41:17,279 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-08-10 10:41:17,280 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-08-10 10:41:17,281 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-08-10 10:41:17,281 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-08-10 10:41:17,282 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-08-10 10:41:17,282 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-08-10 10:41:17,283 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-08-10 10:41:17,284 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-08-10 10:41:17,285 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-08-10 10:41:17,285 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-08-10 10:41:17,500 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1000W_stage3_asn.json',).
# 2022-08-10 10:41:17,506 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-08-10 10:41:17,714 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02103_00009_mirimage_fixed_wcs_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-08-10 10:41:17,726 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-08-10 10:41:17,727 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-08-10 10:41:17,728 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 10:41:17,730 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-08-10 10:41:20,026 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-08-10 10:41:20,028 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-08-10 10:41:20,028 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-08-10 10:41:20,047 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-08-10 10:41:20,248 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-08-10 10:41:20,249 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-08-10 10:41:20,250 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-08-10 10:41:20,268 - stpipe.Image3Pipeline.skymatch - INFO - Step skymat
- stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:42:29,805 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:42:30,769 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:42:31,733 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 10:42:32,089 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.730837396 -73.445850012 110.776478614 -73.478729139 110.888900330 -73.466043319 110.843076242 -73.433188664
# 2022-08-10 10:42:33,028 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_i2d.fits
# 2022-08-10 10:42:33,029 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-08-10 10:42:33,250 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1157, 1126) from miri_F1000W_stage3_asn_i2d.fits>,).
# 2022-08-10 10:42:33,252 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-08-10 10:42:33,268 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-08-10 10:42:33,277 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-08-10 10:42:33,278 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-08-10 10:42:33,279 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-08-10 10:42:33,279 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1000W
# 2022-08-10 10:42:33,279 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-08-10 10:42:33,361 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.95551
# 2022-08-10 10:42:33,431 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1157, 1126).
# 2022-08-10 10:42:33,625 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 62 sources
# 2022-08-10 10:42:33,911 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1000W/stage3/miri_F1000W_stage3_asn_cat.ecsv
# 2022-08-10 10:42:34,155 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_segm.fits
# 2022-08-10 10:42:34,157 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1000W_stage3_asn_segm.fits
# 2022-08-10 10:42:34,158 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-08-10 10:42:34,160 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_catalog_file = output_dir + miri_asn_name + '_cat.ecsv'

# %%
# Open the mosaic image
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
# Read in the source catalog
miri_source_cat = ascii.read(miri_catalog_file)

# %%
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)

# %%
# Look at the mosaic data read noise uncertainties (i.e., coverage map)
show_image(miri_mosaic.var_rnoise, vmin=0.0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic data poisson uncertainties
show_image(miri_mosaic.var_poisson, vmin=0, vmax=0.01, dmap=dmap)

# %%
# Look at the mosaic total data uncertainties
show_image(miri_mosaic.err, vmin=0, vmax=0.2, dmap=dmap)

# %%
# Show the catalog sources on the mosaic
overlay_catalog(miri_mosaic.data, miri_source_cat, flux_limit=5e-7, vmin=drange[0], vmax=drange[1],
                title='Final MIRI mosaic with source catalog', dmap=dmap)
