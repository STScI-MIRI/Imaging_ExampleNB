# %% [markdown]
# ## F1000W - SMACS0723 - col/row pull up down cleaning
#
# Author: Karl Gordon
#
# Last modified: 10 Aug 2022

# %% [markdown]
# ### Variables controling processing and display

# %%
filter = "F1000W"
fwhm = 2.9
exclude_above = None
ds9point = "rowcol_points.reg"

crval = [110.8261940446365, -73.45398878295636]
# rotation = 63.0
# crval = None
rotation = None

tweakreg = False
align_to_gaia = False

matchbkg = False

# display range for images
drange_cal = [-0.1, 5.0]
dmap = "afmhot"  # same as ds9 bb

run_cc_image3 = True

# %%
import os
import glob
import copy

from astropy.io import ascii, fits
from astropy.visualization import simple_norm

# %%
import astropy
print(astropy.__version__)
# Out:
# 5.0.4

# %%
os.environ["CRDS_PATH"] = "/home/kgordon/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-pub.stsci.edu"

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid

# Use this version for non-interactive plots (easier scrolling of the notebook)
# %matplotlib inline

# Use this version (outside of Jupyter Lab) if you want interactive plots
#%matplotlib notebook

# These gymnastics are needed to make the sizes of the figures
# be the same in both the inline and notebook versions
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}

mpl.rcParams['savefig.dpi'] = 80
mpl.rcParams['figure.dpi'] = 80

# %%
# List of possible data quality flags
from jwst.datamodels import dqflags
from jwst import datamodels

from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# custom helper routines
from helpers.jwst_helpers import show_image
from helpers.miri_clean import make_sky, fix_rowcol_pull_updown
from helpers.miri_helpers import miri_image3

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.6.2.dev4+g35d5e1d

# %% [markdown]
# ### Clean col/row pull up/down if desired

# %%
if ds9point is not None:
    miri_cal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_wcs_skysub_cal.fits")
    for cfile in miri_cal_files:
        fix_rowcol_pull_updown(cfile, ds9point, xwidth=40, ywidth=40, xoffset=100, yoffset=100, cortype=None)  # ["topbotright"])
# Out:
# on image ./F1000W/stage2/jw02736002001_02103_00007_mirimage_fixed_wcs_skysub_cal.fits
# on image ./F1000W/stage2/jw02736002001_02103_00004_mirimage_fixed_wcs_skysub_cal.fits
# on image ./F1000W/stage2/jw02736002001_02103_00006_mirimage_fixed_wcs_skysub_cal.fits
# on image ./F1000W/stage2/jw02736002001_02103_00003_mirimage_fixed_wcs_skysub_cal.fits
# on image ./F1000W/stage2/jw02736002001_02103_00002_mirimage_fixed_wcs_skysub_cal.fits
# on image ./F1000W/stage2/jw02736002001_02103_00010_mirimage_fixed_wcs_skysub_cal.fits
# on image ./F1000W/stage2/jw02736002001_02103_00008_mirimage_fixed_wcs_skysub_cal.fits

# %% [markdown]
# ### rerun CALWEBB_IMAGE3 with the new cleaned files

# %%
if run_cc_image3:
    miri_cccal_files = glob.glob(f"./{filter}/stage2/*ge_fixed_wcs_skysub_cal_colrow.fits")
    output_dir = f"./{filter}/stage3/"
    print(miri_cccal_files)

    if rotation is not None:
        miri_asn_name = f'miri_{filter}_stage3_nirproj_asn_skysub_colrow'
    else: 
        miri_asn_name = f'miri_{filter}_stage3_asn_skysub_colrow'
    miri_asn = asn_from_list.asn_from_list(miri_cccal_files, rule=DMS_Level3_Base, product_name=miri_asn_name)

    miri_asn_file = f'{miri_asn_name}.json'
    with open(miri_asn_file, 'w') as outfile:
        name, serialized = miri_asn.dump(format='json')
        outfile.write(serialized)
# Out:
# ['./F1000W/stage2/jw02736002001_02103_00004_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00005_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00003_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00006_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00010_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00002_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00009_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00001_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00007_mirimage_fixed_wcs_skysub_cal_colrow.fits', './F1000W/stage2/jw02736002001_02103_00008_mirimage_fixed_wcs_skysub_cal_colrow.fits']

# %%
if run_cc_image3:
    miri_image3(miri_asn_file, output_dir, fwhm=fwhm, matchbkg=matchbkg,
                crval=crval, rotation=rotation,
                tweakreg=tweakreg, align_to_gaia=align_to_gaia)
# Out:
# 2022-08-10 11:07:18,559 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-08-10 11:07:18,560 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': None, 'class': ''}
#
#
# 2022-08-10 11:07:18,560 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-08-10 11:07:18,562 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.5, 'snr_threshold': 10.0, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 2.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'rshift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False, 'class': ''}
#
#
# 2022-08-10 11:07:18,562 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-08-10 11:07:18,563 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1, 'class': ''}
#
#
# 2022-08-10 11:07:18,564 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-08-10 11:07:18,565 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': None, 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'class': ''}
#
#
# 2022-08-10 11:07:18,565 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-08-10 11:07:18,566 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': None, 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'override_drizpars': None, 'class': ''}
#
#
# 2022-08-10 11:07:18,566 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-08-10 11:07:18,567 - stpipe - CRITICAL - config: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': None, 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8, 'override_apcorr': None, 'override_abvegaoffset': None, 'class': ''}
#
#
# 2022-08-10 11:07:18,568 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-08-10 11:07:18,683 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('miri_F1000W_stage3_asn_skysub_colrow.json',).
# 2022-08-10 11:07:18,688 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './F1000W/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-08-10 11:07:18,891 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw02736002001_02103_00004_mirimage_fixed_wcs_skysub_cal_colrow.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-08-10 11:07:19,211 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2022-08-10 11:07:19,213 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits'.
# 2022-08-10 11:07:19,214 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2022-08-10 11:07:19,215 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-08-10 11:07:21,535 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2022-08-10 11:07:21,537 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 2.9, 'snr_threshold': 5, 'brightest': 200, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 5, 'searchrad': 5.0, 'use2dhist': True, 'separation': 1.0, 'tolerance': 0.7, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}
# 2022-08-10 11:07:21,537 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2022-08-10 11:07:21,556 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2022-08-10 11:07:21,694 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2022-08-10 11:07:21,696 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': 0.0, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2022-08-10 11:07:21,696 - stpipe.Image3Pipeline.skymatch - INFO - Step skipped.
# 2022-08-10 11:07:21,715 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2022-08-10 11:07:21,858 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2022-08-10 11:07:21,859 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2022-08-10 11:07:21,866 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 10 inputs
# 2022-08-10 11:07:22,838 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:23,956 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:25,081 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:26,190 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:27,306 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:28,418 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:29,526 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:30,636 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:31,752 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:32,866 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1147, 1116)
# 2022-08-10 11:07:33,933 - stpipe.Image3Pipeline.outlier_detection - INFO - Generating median from 10 images
# 2022-08-10 11:07:34,739 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2022-08-10 11:07:35,681 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:36,666 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:37,656 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:38,550 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:39,449 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:40,361 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:41,265 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:42,178 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:43,069 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:43,994 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1147, 1116)
# 2022-08-10 11:07:44,035 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2022-08-10 11:07:44,119 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 194 (0.02%)
# 2022-08-10 11:07:44,202 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 242 (0.02%)
# 2022-08-10 11:07:44,282 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 232 (0.02%)
# 2022-08-10 11:07:44,389 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 254 (0.02%)
# 2022-08-10 11:07:44,488 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 357 (0.03%)
# 2022-08-10 11:07:44,572 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 1319 (0.12%)
# 2022-08-10 11:07:44,654 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 299 (0.03%)
# 2022-08-10 11:07:44,736 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 376 (0.04%)
# 2022-08-10 11:07:44,818 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 236 (0.02%)
# 2022-08-10 11:07:44,899 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 214 (0.02%)
# 2022-08-10 11:07:45,902 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00004_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:47,046 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00005_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:48,007 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00003_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:49,003 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00006_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:49,990 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00010_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:50,984 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00002_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:51,955 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00009_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:52,920 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00001_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:53,892 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00007_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:54,866 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./F1000W/stage3/jw02736002001_02103_00008_mirimage_fixed_wcs_skysub_cal_colrow_a3001_crf.fits
# 2022-08-10 11:07:54,866 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2022-08-10 11:07:55,021 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2022-08-10 11:07:55,023 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': [110.8261940446365, -73.45398878295636], 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.11, 'single': False, 'blendheaders': True, 'allowed_memory': None}
# 2022-08-10 11:07:55,038 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2022-08-10 11:07:55,266 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for miri_F1000W_stage3_asn_skysub_colrow
# 2022-08-10 11:07:56,041 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-08-10 11:07:56,682 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:07:57,641 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:07:58,596 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:07:59,557 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:00,481 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:01,443 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:02,401 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:03,354 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:04,310 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:05,281 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:05,619 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-08-10 11:08:06,215 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:07,237 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:08,255 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:09,257 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:10,253 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:11,263 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:12,269 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:13,272 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:14,269 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:15,269 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:15,655 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-08-10 11:08:16,315 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:17,315 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:18,334 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:19,340 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:20,343 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:21,355 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:22,355 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:23,357 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:24,358 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:25,360 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:25,756 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-08-10 11:08:26,374 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:27,369 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:28,368 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:29,366 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:30,364 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:31,368 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:32,367 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:33,364 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:34,361 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:35,366 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1157, 1126)
# 2022-08-10 11:08:35,775 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  110.730837043 -73.445849643 110.776476958 -73.478728916 110.888899177 -73.466043456 110.843076387 -73.433188655
# 2022-08-10 11:08:36,749 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_skysub_colrow_i2d.fits
# 2022-08-10 11:08:36,749 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-08-10 11:08:36,909 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1157, 1126) from miri_F1000W_stage3_asn_skysub_colrow_i2d.fits>,).
# 2022-08-10 11:08:36,911 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 5, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-08-10 11:08:36,929 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.fits
# 2022-08-10 11:08:36,939 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2022-08-10 11:08:36,941 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2022-08-10 11:08:36,941 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2022-08-10 11:08:36,941 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1000W
# 2022-08-10 11:08:36,941 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-08-10 11:08:37,015 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 4.95551
# 2022-08-10 11:08:37,083 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1157, 1126).
# 2022-08-10 11:08:37,287 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 133 sources
# 2022-08-10 11:08:37,601 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./F1000W/stage3/miri_F1000W_stage3_asn_skysub_colrow_cat.ecsv
# 2022-08-10 11:08:37,838 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./F1000W/stage3/miri_F1000W_stage3_asn_skysub_colrow_segm.fits
# 2022-08-10 11:08:37,840 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: miri_F1000W_stage3_asn_skysub_colrow_segm.fits
# 2022-08-10 11:08:37,840 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-08-10 11:08:37,842 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %%
# Look at the resulting mosaic image
miri_mosaic_file = output_dir + miri_asn_name + '_i2d.fits'
miri_mosaic = datamodels.open(miri_mosaic_file)

# %%
drange = drange_cal
# Look at the mosaic
show_image(miri_mosaic.data, vmin=drange[0], vmax=drange[1], dmap=dmap)
